# %% [markdown]
# **CREATED BY THEWAVEWY (PIYOUNGGUL SUPARSORN)**

# %% [markdown]
# CODE นี้ใช้สำหรับดึงข้อมูลสถานีวัดมลพิษทั่วประเทศไทย และค่ามลพิษที่วัดได้ (PM2.5, PM10) ที่วัดได้จากข้อมูลของ [cusense.net](https://cusense.net/map) API

# %% [markdown]
# ข้อมูลที่ได้จะเป็นข้อมูลที่ได้ในแต่ละวัน โดยในงานนี้นิสิตใช้ข้อมูลของวันที่ 9 กรกฎาคม 2566 ถ้าผู้สนใจต้องการใช้ ก็จะได้ข้อมูลของเครื่องวัด ณ วันและเวลานั้นๆทันที

# %% [markdown]
# ข้อมูลที่ได้จะจัดเก็บอยู่ใน Local Memory ของ Google Colab ในรูป .csv

# %% [markdown]
# # **ข้อมูลของสถานีต่างๆ**

# %% [markdown]
# **Returns every station's information in the database**

# %%
import requests

# Define the API endpoint URL
url1 = 'https://www.cusense.net:8082/api/v1/stationInfo/all'

# Define the headers
headers = {
    'Content-Type': 'application/json',
    'X-Gravitee-Api-Key': '7be9f42f-7e74-4822-972d-5c1e3e783c9d'
}

# Send a GET request to the API endpoint with the headers
response = requests.get(url1, headers=headers)

# Check the response status code
if response.status_code == 200:
    # Successful request
    all_station = response.json()
    print(all_station)
else:
    # Error handling
    print('Request failed with status code:', response.status_code)
# Out:
# {'cusensor/CU-01': {'topic': 'cusensor/CU-01', 'project': 'cusensor', 'id': 'CU-01', 'lat': '13.735661', 'lon': '100.532588', 'name': 'ภาควิชาวิศวกรรมสิ่งแวดล้อม, จุฬา', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor/CU-S0203': {'topic': 'cusensor/CU-S0203', 'project': 'cusensor', 'id': 'CU-0203', 'lat': '11.570522', 'lon': '104.896714', 'name': 'Institute of Technology of Cambodia (ITC)', 'tambol': 'Teuk lak ti 1', 'amphoe': 'Toulkok', 'province': 'Phnom Penh'}, 'cusensor/MET.SK.TEEGA': {'topic': 'cusensor/MET.SK.TEEGA', 'project': 'cusensor', 'id': 'MET.SK.TEEGA', 'lat': '14.918769', 'lon': '104.137828', 'name': 'ฝายตีกา', 'tambol': 'ศรีสำราญ', 'amphoe': 'วังหิน', 'province': 'ศรีสะเกษ'}, 'cusensor/RKN-001': {'topic': 'cusensor/RKN-001', 'project': 'cusensor', 'id': 'RKN-001', 'lat': '11.580575', 'lon': '104.930686', 'name': 'Resident House (RS)', 'tambol': 'Phum 1', 'amphoe': 'Chroy Changva', 'province': 'Phnom Penh'}, 'cusensor/RKN-002': {'topic': 'cusensor/RKN-002', 'project': 'cusensor', 'id': 'RKN-002', 'lat': '11.476056', 'lon': '104.784333', 'name': 'Phnom Penh Special Economic Zone (PPSEZ)', 'tambol': 'Kantoak', 'amphoe': 'Porsenchey', 'province': 'Phnom Penh'}, 'cusensor/SMSK_RRS': {'topic': 'cusensor/SMSK_RRS', 'project': 'cusensor', 'id': 'SMSK_RRS', 'lat': '13.591248', 'lon': '100.329737', 'name': 'โรงเรียนราษฏร์รังสรรค์', 'tambol': 'คอกกระบือ', 'amphoe': 'เมืองสมุทครสาคร', 'province': 'สมุทรสาคร'}, 'cusensor2/0424D01F9C9C': {'topic': 'cusensor2/0424D01F9C9C', 'project': 'cusensor2', 'id': '0424D01F9C9C', 'lat': '13.738300', 'lon': '100.528816', 'name': 'จามจุรี 5 ชั้น 3', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/0C44F5C40A24': {'topic': 'cusensor2/0C44F5C40A24', 'project': 'cusensor2', 'id': '0C44F5C40A24', 'lat': '13.742675', 'lon': '100.528077', 'name': 'จามจุรี 10 ชั้น 11', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/40F5203F054B': {'topic': 'cusensor2/40F5203F054B', 'project': 'cusensor2', 'id': '40F5203F054B', 'lat': '13.734200', 'lon': '100.533050', 'name': 'Stockholm Environment Institute (SEI) (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/40F5203F0828': {'topic': 'cusensor2/40F5203F0828', 'project': 'cusensor2', 'id': '40F5203F0828', 'lat': '13.742930', 'lon': '100.532150', 'name': 'ห้องปฏิบัติการเคมี สถาบันวิจัยสภาวะแวดล้อม (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/40F5203F7FBF': {'topic': 'cusensor2/40F5203F7FBF', 'project': 'cusensor2', 'id': '40F5203F7FBF', 'lat': '13.736020', 'lon': '100.530590', 'name': 'ภาควิชาเคมีเทคนิค ชั้น ห้อง 1810 อาคารมหามกุฎ (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/40F5203F88E0': {'topic': 'cusensor2/40F5203F88E0', 'project': 'cusensor2', 'id': '40F5203F88E0', 'lat': '13.742830', 'lon': '100.528250', 'name': 'EDS Program (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/40F5203F8E86': {'topic': 'cusensor2/40F5203F8E86', 'project': 'cusensor2', 'id': '40F5203F8E86', 'lat': '13.742700', 'lon': '100.532780', 'name': 'วิทยาลัยวิทยาศาสตร์สาธารณสุข (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/60019440B7A6': {'topic': 'cusensor2/60019440B7A6', 'project': 'cusensor2', 'id': '60019440B7A6', 'lat': '13.732152', 'lon': '100.537307', 'name': 'อาคารภูมิสิริ ชั้น 1 (หน้า ER) (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/60019440B7B7': {'topic': 'cusensor2/60019440B7B7', 'project': 'cusensor2', 'id': '60019440B7B7', 'lat': '13.732318', 'lon': '100.537199', 'name': 'อาคารภูมิสิริ ชั้น 14 (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}, 'cusensor2/60019440B808': {'topic': 'cusensor2/60019440B808', 'project': 'cusensor2', 'id': '60019440B808', 'lat': '13.735188', 'lon': '100.532189', 'name': 'สถาบันภาษา', 'tambol': ...

# %%
all_station['cusensor/CU-01']
# Out:
# {'topic': 'cusensor/CU-01',
#  'project': 'cusensor',
#  'id': 'CU-01',
#  'lat': '13.735661',
#  'lon': '100.532588',
#  'name': 'ภาควิชาวิศวกรรมสิ่งแวดล้อม, จุฬา',
#  'tambol': 'วังใหม่',
#  'amphoe': 'ปทุมวัน',
#  'province': 'กรุงเทพ'}

# %%
all_station.keys()
# Out:
# dict_keys(['cusensor/CU-01', 'cusensor/CU-S0203', 'cusensor/MET.SK.TEEGA', 'cusensor/RKN-001', 'cusensor/RKN-002', 'cusensor/SMSK_RRS', 'cusensor2/0424D01F9C9C', 'cusensor2/0C44F5C40A24', 'cusensor2/40F5203F054B', 'cusensor2/40F5203F0828', 'cusensor2/40F5203F7FBF', 'cusensor2/40F5203F88E0', 'cusensor2/40F5203F8E86', 'cusensor2/60019440B7A6', 'cusensor2/60019440B7B7', 'cusensor2/60019440B808', 'cusensor2/60019440B80B', 'cusensor2/60019440B8BA', 'cusensor2/60019440B940', 'cusensor2/60019440B94A', 'cusensor2/68C63A8E5B80', 'cusensor2/68C63A8E5BB6', 'cusensor2/68C63A8E5BBF', 'cusensor2/869405031319016', 'cusensor2/869405031319123', 'cusensor2/869405031343719', 'cusensor2/B01ED01F9C9C', 'cusensor2/D478F5C40A24', 'cusensor2/D8A01D611814', 'cusensor2/D8A01D611C90', 'cusensor3/0862CD09F0B8', 'cusensor3/240AC4586964', 'cusensor3/240AC4588CF8', 'cusensor3/240AC4589680', 'cusensor3/240AC458FE8C', 'cusensor3/240AC4591554', 'cusensor3/240AC459213C', 'cusensor3/240AC4592908', 'cusensor3/240AC4C656F8', 'cusensor3/240AC4C66068', 'cusensor3/240AC4C660E0', 'cusensor3/246F289CF9C4', 'cusensor3/246F289D7CE8', 'cusensor3/246F289D7F1C', 'cusensor3/246F289E11D4', 'cusensor3/246F289E1BE4', 'cusensor3/246F289E906C', 'cusensor3/246F289E966C', 'cusensor3/246F289EA1B4', 'cusensor3/246F289EA56C', 'cusensor3/246F289EA798', 'cusensor3/246F28AE0ABC', 'cusensor3/246F28B45C80', 'cusensor3/246F28B4FFB8', 'cusensor3/7C9EBDF4DC28', 'cusensor3/7C9EBDF4DCE4', 'cusensor3/7C9EBDF4DE94', 'cusensor3/7C9EBDF4E32C', 'cusensor3/7C9EBDF4E430', 'cusensor3/7C9EBDF4E780', 'cusensor3/7C9EBDF4E7C4', 'cusensor3/7C9EBDF4EAA4', 'cusensor3/7C9EBDF50438', 'cusensor3/7C9EBDF54B80', 'cusensor3/84CE54A8CC84', 'cusensor3/8CAAB584DBF0', 'cusensor3/8CAAB584E208', 'cusensor3/8CAAB5851AD4', 'cusensor3/8CAAB58527DC', 'cusensor3/8CAAB5852984', 'cusensor3/8CCE54A8CC84', 'cusensor3/B8F009CD02D0', 'cusensor3/B8F009CD03A8', 'cusensor3/B8F009CD07DC', 'cusensor3/B8F009CD0E18', 'cusensor3/B8F009CD112C', 'cusensor3/B8F009CD113C', 'cusensor3/B8F009CD1878', 'cusensor3/B8F009CD18F4', 'cusensor3/B8F009CD1DB4', 'cusensor3/B8F009CD1E28', 'cusensor3/B8F009CD1F20', 'cusensor3/B8F009CD2094', 'cusensor3/E861A0F23A08', 'Dustboy/10', 'Dustboy/100', 'Dustboy/104', 'Dustboy/105', 'Dustboy/106', 'Dustboy/108', 'Dustboy/109', 'Dustboy/110', 'Dustboy/116', 'Dustboy/117', 'Dustboy/118', 'Dustboy/119', 'Dustboy/12', 'Dustboy/121', 'Dustboy/122', 'Dustboy/123', 'Dustboy/13', 'Dustboy/14', 'Dustboy/16', 'Dustboy/17', 'Dustboy/18', 'Dustboy/19', 'Dustboy/2', 'Dustboy/20', 'Dustboy/2002', 'Dustboy/2003', 'Dustboy/2004', 'Dustboy/2005', 'Dustboy/2006', 'Dustboy/22', 'Dustboy/23', 'Dustboy/24', 'Dustboy/25', 'Dustboy/26', 'Dustboy/27', 'Dustboy/28', 'Dustboy/29', 'Dustboy/30', 'Dustboy/3001', 'Dustboy/3002', 'Dustboy/31', 'Dustboy/32', 'Dustboy/33', 'Dustboy/34', 'Dustboy/35', 'Dustboy/36', 'Dustboy/37', 'Dustboy/38', 'Dustboy/39', 'Dustboy/4', 'Dustboy/40', 'Dustboy/4002', 'Dustboy/4003', 'Dustboy/4004', 'Dustboy/4005', 'Dustboy/4006', 'Dustboy/4007', 'Dustboy/4008', 'Dustboy/4009', 'Dustboy/4010', 'Dustboy/4011', 'Dustboy/4012', 'Dustboy/4013', 'Dustboy/4014', 'Dustboy/4015', 'Dustboy/4016', 'Dustboy/4017', 'Dustboy/4018', 'Dustboy/4019', 'Dustboy/4020', 'Dustboy/4021', 'Dustboy/4022', 'Dustboy/4023', 'Dustboy/4026', 'Dustboy/4027', 'Dustboy/4031', 'Dustboy/4032', 'Dustboy/4033', 'Dustboy/4034', 'Dustboy/4035', 'Dustboy/4036', 'Dustboy/4037', 'Dustboy/4038', 'Dustboy/4039', 'Dustboy/4040', 'Dustboy/4041', 'Dustboy/4042', 'Dustboy/4043', 'Dustboy/4044', 'Dustboy/4045', 'Dustboy/4046', 'Dustboy/4047', 'Dustboy/4048', 'Dustboy/4049', 'Dustboy/4061', 'Dustboy/4062', 'Dustboy/4063', 'Dustboy/4064', 'Dustboy/4065', 'Dustboy/4066', 'Dustboy/4067', 'Dustboy/4068', 'Dustboy/4069', 'Dustboy/4070', 'Dustboy/4071', 'Dustboy/4072', 'Dustboy/4073', 'Dustboy/4074', 'Dustboy/4075', 'Dustboy/4077', 'Dustboy/4078', 'Dustboy/4079', 'Dustboy/4080', 'Dustboy/4103', 'Dustboy/4104', 'Dustboy/43', 'Dustboy/44', 'Dustboy/45', 'Dustboy/46', 'Dustbo ...

# %%
sen = list(all_station.keys())

# %%
Name = []
for i in sen:
  name = all_station[i]['name']
  Name.append(name)

# %%
Name
# Out:
# ['ภาควิชาวิศวกรรมสิ่งแวดล้อม, จุฬา',
#  'Institute of Technology of Cambodia (ITC)',
#  'ฝายตีกา',
#  'Resident House (RS)',
#  'Phnom Penh Special Economic Zone (PPSEZ)',
#  'โรงเรียนราษฏร์รังสรรค์',
#  'จามจุรี 5 ชั้น 3',
#  'จามจุรี 10 ชั้น 11',
#  'Stockholm Environment Institute (SEI) (Indoor)',
#  'ห้องปฏิบัติการเคมี สถาบันวิจัยสภาวะแวดล้อม (Indoor)',
#  'ภาควิชาเคมีเทคนิค ชั้น ห้อง 1810 อาคารมหามกุฎ (Indoor)',
#  'EDS Program (Indoor)',
#  'วิทยาลัยวิทยาศาสตร์สาธารณสุข (Indoor)',
#  'อาคารภูมิสิริ ชั้น 1 (หน้า ER) (Indoor)',
#  'อาคารภูมิสิริ ชั้น 14 (Indoor)',
#  'สถาบันภาษา',
#  'สาธิตจุฬาประถม ประตู 5',
#  'หอสมุดกลาง (Indoor)',
#  'โรงอาหารหอพักนิสิต จุฬาฯ',
#  'สาธิตจุฬาประถม ประตู 3',
#  'โรงยิมจุฬาฯ\r\n',
#  'จุฬาพัฒน์ 14',
#  'หอสมุดกลาง ภายนอกอาคาร ',
#  'สวน 100 ปี (พื้นที่สูง)',
#  'สวน 100 ปี (ข้างสระน้ำ)',
#  'สวน 100 ปี (Ampark)',
#  'จามจุรี 9 ชั้น 3',
#  'มหามกุฏ คณะวิทยาศาสตร์',
#  'สาธิตจุฬาประถม โรงอาหารฝั่งริมถนน',
#  'สาธิตจุฬาประถม สนามฟุตบอลใน',
#  'โรงเรียนวัดดวงแข',
#  'อบต.ศรีภูมิ',
#  'โรงเรียนสา (1)',
#  'อบต.ยม',
#  'อบต.นาซาว',
#  'รพ.สต.สันทะ',
#  'โรงเรียนสา (2)',
#  'อบต.ศิลาเพชร',
#  'วิทยนิเวศน์',
#  'โรงอาหารรวม',
#  'ภาควิชาวิศวกรรมโยธา',
#  'โรงพยาบาลสัตว์เล็ก',
#  'โรงพยาบาลสัตว์เล็ก(อาคารสัตววิทยวิจักษ์)',
#  'อาคาร 60 ปี',
#  'อาคารวิศว 100 ปี',
#  'คณะสหเวชศาสตร์',
#  'คณะวิทยาศาสตร์การกีฬา',
#  'อาคาร 50 ปี ',
#  'คณะสถาปัตยกรรมศาสตร์',
#  'อาคารวิศิษฐ์ ประจวบเหมาะ',
#  'ห้องพัสดุ วิศวกรรมศาสตร์',
#  'โรงอาหารจุลจักรพงษ์',
#  'Live&Learn คณะวิศวกรรมศาสตร์',
#  'ภาควิชาวิศวกรรมสำรวจ',
#  'รพ.สต.ไหล่น่าน',
#  'อบต.เมืองจัง',
#  'อบต.สันทะ',
#  'ทต.ทุ่งช้าง',
#  'อบต.นาปัง',
#  'ศูนย์ภูฟ้าพัฒนาอันเนื่องมาจากพระราชดำริฯ',
#  'ทต.กองควาย',
#  'อบต.สะเนียน',
#  'โรงเรียนบ้านปงสนุก',
#  'รพ.สต.แงง',
#  'โรงเรียนวัดปทุมวนาราม',
#  'รพ.สต.เจดีย์ชัย',
#  'อบต.เชียงของ',
#  'อุทยานแห่งชาติแม่ปิง',
#  'ทต.ปัว',
#  'ทต.ก้อ',
#  'โรงเรียนสวนลุมพินี',
#  'อบต.จอมจันทร์',
#  'อบต.ผาตอ',
#  'โรงเรียนบ้านนาวงศ์',
#  'รร.บ้านน้ำฮาว',
#  'อบต.แสนทอง',
#  'โรงเรียนบ้านไหล่น่าน',
#  'อบต.และ',
#  'รร.บ้านยู้',
#  'ทต.กลางเวียง',
#  'โรงเรียนรวมบ้านขึ่งงามมงคล',
#  'อบต.เรือง',
#  'ม.ราชภัฏเชียงใหม่',
#  'โรงเรียนวัดชัยมงคล',
#  'สำนักงานการวิจัยแห่งชาติ กรุงเทพฯ',
#  'ม. สุขภาพ ลาว 3',
#  'สถานีอุตุนิยมวิทยา จ. ลำพูน',
#  'ศาลากลาง จ. ลำพูน ',
#  'ม. เทคโนโลยีราชมงคลล้านนา จ. เชียงใหม่ จุดที่ 1 ',
#  ' รร. เรยีนาเชลีวิทยาลัย จ. เชียงใหม่',
#  'คณะบริหารธุรกิจ มหาวิทยาลัยเชียงใหม่',
#  'มูลนิธิเพื่อเด็กพิการ กรุงเทพฯ',
#  'ศูนย์วิจัยโรคเขตร้อน ม. มหิดล จ. กาญจนบุรี',
#  'คณะสาธารณสุขศาสตร์ มรภ.วไลยอลงกรณ์',
#  'มหาวิทยาลัยวลัยลักษณ์ จ. นครศรีธรรมราช ',
#  'รพ. เวชศาสตร์เขตร้อน กรุงเทพฯ',
#  "Bear Hug Cafe' ต. ช้างคลาน จ. เชียงใหม่",
#  'ศูนย์กีฬาสิรินธร ม. ศรีนครินทรวิโรฒ จ. นครนายก',
#  'ศาลาว่าการกรุงเทพมหานคร',
#  'พาร์ค แอด สยาม จุฬาลงกรณ์มหาวิทยาลัย กรุงเทพฯ',
#  'รพ. แม่แตง จ. เชียงใหม่',
#  'รพ. ฝาง จ. เชียงใหม่',
#  'รพ. ฮอด จ. เชียงใหม่',
#  'รพ. สันป่าตอง จ. เชียงใหม่',
#  'รพ. แม่ออน จ. เชียงใหม่',
#  'รพ. สารภี จ. เชียงใหม่',
#  'Between: Smart Farm&Cafe ต. แม่แรม จ. เชียงใหม่',
#  'ม. เทคโนโลยีราชมงคลล้านนา (ดอยสะเก็ด) เชียงใหม่',
#  'สำนักงานเขต บริษัท ทรู จ. เชียงใหม่ ',
#  'โรงเรียนบ้านก้อจัดสรร อ. ลี้ จ. ลำพูน',
#  'คณะวิศวกรรมศาสตร์ มหาวิทยาลัยเชียงใหม่ ',
#  'สวนสาธารณะหนองบวกหาด ต. พระสิงห์ จ. เชียงใหม่',
#  'บริษัท เอไอเอ จ. เชียงใหม่',
#  'รพ. ดอยสะเก็ด จ. เชียงใหม่',
#  'รพ. สันกำแพง จ. เชียงใหม่',
#  'รพ. หางดง จ. เชียงใหม่',
#  'รพ. สะเมิง จ. เชียงใหม่',
#  'รพ. แม่วาง จ. เชียงใหม่',
#  'รพ. ดอยหล่อ จ. เชียงใหม่',
#  'สสอ. จอมทอง จ. เชียงใหม่',
#  'รพ. ดอยเต่า จ. เชียงใหม่',
#  'รพ. อมก๋อย จ. เชียงใหม่',
#  'รพ. กรุงเทพระยอง จุดที่ 1 จ. ระยอง',
#  'รพ. กรุงเทพระยอง จุดที่ 2 จ. ระยอง',
#  'รพ. เทพรัตนเวชชานุกูล จ. เชียงใหม่',
#  'รพ. วัดจันทร์เฉลิมพระเกียรติ จ. เชียงใหม่',
#  'สสอ. เชียงดาว จ. เชียงใหม่',
#  'รพ. เวียงแหง จ. เชียงใหม่',
#  'รพ. ไชยปราการ จ. เชียงใหม่',
#  'สสอ. แม่อาย จ. เชียงใหม่',
#  'รพ. ส่งเสริมสุขภาพ เขต 1 จ. เชียงใหม่',
#  'รพ. นครพิงค์ จ. เชียงใหม่',
#  'มูลนิธิทรัพยากรธรรมชาติและสิ่่งแวดล้อม (น้ำรี) จ. น่าน',
#  'ไนท์บาร์ซาร์ จ. เชียงใหม่',
#  'มูลนิธิเพื่อทรัพยากรธรรมชาติและสิ่งแวดล้อม (น้ำช้าง) จ. น่าน',
#  'มหาวิทยาลัยนอร์ท-เชียงใหม่ จ. เชียงใหม่',
#  'ทางหลวงหมายเลข 121 บริเวณสี่แยกแม่กวง จ. เชียงใหม่',
#  'ทางหลวงหมายเลข 121 บริเวณสี่แยกแม่กวง จ. เชียงใหม่',
#  'ทางหลวงหมายเลข 121 บริเวณสี่แยกแม่กวง จ. เชียงใหม่',
#  'ทางหลวงหมายเลข 121 บริเวณสี่แยกแม่กวง จ. เชียงใหม่',
#  'ทางหลวงหมายเลข 121 บริเวณสี่แยกแม่กวง จ. เชียงใหม่',
#  'ทางลอดอุโมงค์ดอนแก้วทางหลวงหมายเลข107 (ถนนโชตนา) จ. เชียงใหม่',
#  'ทางลอดอุโมงค์ดอนแก้วทางหลวงหมายเลข107 (ถนนโชตนา) จ. เชียงใหม่',
#  'ทางลอดอุโมงค์ดอนแก้วทางหลวงหมายเลข107 (ถนนโชตนา) จ. เชียงใหม่',
#  'ทางลอดอุโมงค์ดอนแก้วทางหลวงหมายเลข107 (ถนนโชตนา) จ. เชียงใหม่',
#  'ทางลอดอุโมงค์ดอนแก้วทางหลวงหมายเลข107 (ถนนโชตนา) จ. เชียงใหม่',
#  'สถาบันพัฒนาสุขภาวะเขตเมือง',
#  'สถาบันพัฒนาสุขภาวะเขตเมือง ',
#  'ม. เทคโนโลยีราชมงคลล้านนา จ. เชียงใหม่ จุดที่ 2',
#  'ม. เทคโนโลยีราชมงคลล้านนา จ. เชียงใหม่ จุดที่ 3',
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลล้านนา (เชียงราย)',
#  'โรงเรียนจันทร์เจ้าวิทยาคม จ. เชียงราย',
#  'มหาวิทยาลัยพะเยา',
#  'ศูนย์การแพทย์และโรงพยาบาลมหาวิทยาลัยพะเยา',
#  'มหาวิทยาลัยพะเยา',
#  'มหาวิทยาลัยพะเยา',
#  'มหาวิทยาลัยพะเยา',
#  'โรงเรียนวารีเชียงใหม่ จุดที่ 1',
#  'โรงเรียนวารีเชียงใหม่ จุดที่ 2',
#  'โรงพยาบาลแม่ฟ้าหลวง จ. เชียงราย',
#  'โรงพยาบาลแม่จัน จ. เชียงราย',
#  'โรงพยาบาลเชียงแสน จ. เชียงราย',
#  'โรงพยาบาลดอยหลวง จ. เชียงราย',
#  'โรงพยาบาลสมเด็จพระยุพราชเชียงของ จ. เชียงราย',
#  'โรงพยาบาลเวียงแก่น จ. เชียงราย',
#  'โรงพยาบาลขุนตาล จ. เชียงราย',
#  'โรงพยาบาลพญาเม็งราย จ. เชียงราย',
#  'โรงพยาบาลเทิง จ. เชียงราย',
#  'โรงพยาบาลป่าแดด จ. เชียงราย',
#  'โรงพยาบาลพาน จ. เชียงราย',
#  'โรงพยาบาลแม่สรวย จ. เชียงราย',
#  'โรงพยาบาลเวียงป่าเป้า จ. เชียงราย',
#  'โรงพยาบาลแม่ลาว จ. เชียงราย',
#  'โรงพยาบาลสมเด็จพระญาณสังวร จ. เชียงราย',
#  'โรงพยาบาลเวียงเชียงรุ้ง จ. เชียงราย',
#  'อบต. ทรงธรรม จ. กำแพงเพชร',
#  'โรงเรียนบ้านโฮ่ง อ. ลี้ จ. ลำพูน',
#  'โรงพยาบาลลี้ อ. ลี้ จ. ลำพูน',
#  'ตลาดสดกรมชลประทาน ทน. ปากเกร็ด',
#  'หน้าเซ็นทรัลแจ้งวัฒนะ ทน. ปากเกร็ด',
#  'หน้าโรงเรียนวัดกลางเกร็ด ทน. ปากเกร็ด',
#  'ซอยสถานสงเคราะห์คนพิการปากเกร็ด ทน. ปากเกร็ด',
#  'ซอยสุขาประชาสวรรค์ 2 ตัด 3 ทน. ปากเกร็ด',
#  'ป้ายรถเมล์หน้าเมเจอร์ฮอลิวูด ทน. ปากเกร็ด',
#  'ร้านเย็นตาโฟโลกันต์ ทน. ปากเกร็ด',
#  'ปากซอยโรงเรียนวัดกู้ ทน. ปากเกร็ด',
#  'หน้าบิ๊กชีแจ้งวัฒนะ ทน. ปากเกร็ด',
#  'หน้าโรงเรียนนวมินทราชินูทิศ หอวัง นนทบุรี ทน. ปากเกร็ด',
#  'หน้าสถาบันการจัดการปัญญาภิวัฒน์ ทน. ปากเกร็ด',
#  'สามแยกติวานนท์-ปากเกร็ด 2 ทน. ปากเกร็ด',
#  'หน้าโรงเรียนวัดบ่อ ทน. ปากเกร็ด',
#  'แยกสวนสมเด็จพระศรีนครินทร์ ทน. ปากเกร็ด',
#  'ถนนแจ้งวัฒนะคลองประปา ทน. ปากเกร็ด',
#  'หน้าโรงเรียนปากเกร็ด ทน. ปากเกร็ด',
#  'หน้าโรงเรียนคลองเกลือ ทน. ปากเกร็ด',
#  'ซอยสุขาประชาสวรรค์3 ซอย26 (รร. อัมพรไพศาล) ทน. ปากเกร็ด',
#  'สี่แยกสหกรณ์ 3 (ถนนเลี่ยงเมือง) ทน. ปากเกร็ด',
#  'อบต. กองแขก จ. เชียงใหม่',
#  'แม่สากรีนเนอร์รี่ฮิลล์',
#  'PhaNomPhen1',
#  'PhaNomPhen2',
#  'HoChiMinh1',
#  'HoChiMinh2',
#  'ด่านพระราม ๔',
#  'Innovative Village ต. ป่าแดด จ. เชียงใหม่',
#  'เครือสหพัฒน์ จ. ลำพูน',
#  'สสอ. ดอกคำใต้ จ. พะเยา',
#  'สสอ. ภูกามยาว จ. พะเยา',
#  'รพ.สต. แม่กา จ. พะเยา',
#  'สสอ. ภูซาง จ. พะเยา',
#  'สสอ. แม่ใจ จ. พะเยา',
#  'รพ. ร้องกวาง จ. แพร่',
#  'รพ.สต. ป่าแดง จ. แพร่',
#  'สำนักงานสาธารณสุขจังหวัดแพร่',
#  'รพ.สต. ไทรย้อย อ.เด่นชัย จ. แพร่',
#  'สำนักงานสาธารณสุข อำเภอหนองม่วงไข่ จ. แพร่',
#  'โรงพยาบาลสูงเม่น จ. แพร่',
#  'รพ.สต. สะเอียบ จ. แพร่',
#  'รพ.สต. ผาคัน จ. แพร่',
#  'รพ.สต. บ้านเวียง จ. แพร่',
#  'รพ.สต. วังลึก จ. แพร่',
#  'โรงพยาบาลแพร่',
#  'รพ.สต. ทุ่งแค้ว จ. แพร่',
#  'รพ.สต. สบสาย จ. แพร่',
#  'โรงพยาบาลสมเด็จพระยุพราชเด่นชัย จ. แพร่',
#  'โรงพยาบาลสอง จ. แพร่',
#  'โรงพยาบาลลอง จ. แพร่',
#  'โรงพยาบาลวังชิ้น จ. แพร่',
#  'รพ.สต. เมืองน้อย จ. แม่ฮ่องสอน',
#  'โรงพยาบาลแม่ลาน้อย จ. แม่ฮ่องสอน',
#  'รพ.สต. นาปู่ป้อม อ. ปางมะผ้า จ. เเม่ฮ่องสอน',
#  'สำนักงานสาธารณสุขจังหวัดแม่ฮ่องสอน',
#  'โรงพยาบาลธัญญารักษ์ แม่ฮ่องสอน',
#  'โรงพยาบาลท่าสองยาง จ. ตาก',
#  'โรงพยาบาลบ้านตาก',
#  'โรงพยาบาลสมเด็จพระเจ้าตากสินมหาราช จ. ตาก',
#  'โรงพยาบาลพบพระ จ. ตาก',
#  'โรงพยาบาลวังเจ้า จ. ตาก',
#  'ศูนย์อนามัยที่ 2 พิษณุโลก',
#  'โรงพยาบาลสมเด็จพระยุพราชนครไทย จ. พิษณุโลก',
#  'โรงพยาบาลพิชัย จ. อุตรดิตถ์',
#  'โรงพยาบาลอุตรดิตถ์',
#  'โรงพยาบาลน้ำปาด จ. อุตรดิตถ์',
#  'สำนักงานสาธารณสุขจังหวัดเพชรบูรณ์',
#  'โรงพยาบาลวิเชียรบุรี จ. เพชรบูรณ์',
#  'ที่ว่าการอำเภอทุ่งเสลี่ยม จ. สุโขทัย',
#  'โรงพยาบาลสวรรคโลก จ. สุโขทัย',
#  'รพ.สต. หมอกจำแป่ จ. แม่ฮ่องสอน',
#  'รพ.สต. น้ำดิบ จ. แม่ฮ่องสอน',
#  'รพ.สต. ต่อแพ จ. แม่ฮ่องสอน',
#  'รพ.สต. บ้านกองก๋อย จ. แม่ฮ่องสอน',
#  'โรงพยาบาลแม่สอด จ. ตาก',
#  'โรงพยาบาลอุ้มผาง จ. ตาก',
#  'รพ.เชียงม่วน จ. พะเยา',
#  'โรงพยาบาลปง จ. พะเยา',
#  'เทศบาลตำบลห้วยข้าวก่ำ',
#  'โรงพยาบาลเชียงคำ จ. พะเยา',
#  'ศูนย์ราชการจังหวัดพะเยา',
#  'โรงพยาบาลพะเยา',
#  'โรงพยาบาลศรีสังวาลย์ จ. แม่ฮ่องสอน',
#  'โรงเรียนเทศบาล 6 (อนุบาลในฝัน) ทน. หาดใหญ่',
#  'ไดอาน่าคอมเพล็กซ์ช็อปปิ้งเซ็นเตอร์ ทน. หาดใหญ่',
#  'ลีการ์เด้นท์พล่าซ่าหาดใหญ่ ทน. หาดใหญ่',
#  ' กองกายภาพและสิ่งแวดล้อม',
#  'ศูนย์การเรียนรู้ ม. มหิดล (ศาลายา)',
#  ' อาคารสิริวิทยา มหาวิทยาลัยมหิดล (ศาลายา)',
#  'สำนักงานอธิการบดี ม. มหิดล (ศาลายา)',
#  'หนองแหน 1 อ. พนมสารคราม จ. ฉะเชิงเทรา',
#  'หนองแหน 2 อ. พนมสารคราม จ. ฉะเชิงเทรา',
#  'โรงเรียนอนุบาลมวกเหล็ก จ. สระบุรี',
#  'อาคารวิศวกรรมโยธา มหาวิทยาลัยนเรศวร (พิษณุโลก)',
#  'โรงเรียนบ้านหัวป้าง จ. นครราชสีมา',
#  'ชุมชนหมู่ 5 บ้านเขามะกอก จ. สระบุรี',
#  'สำนักงานเทศบาลตำบลปริก',
#  'สนามกีฬาจิระนคร ',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดสงขลา',
#  'สํานักงานเทศบาลเมืองกันตัง จ. ตรัง',
#  'สำนักงานเทศบาลเมืองทุ่งสง',
#  'สำนักงานเทศบาลนครยะลา',
#  'รพ.สต. แม่ลาหลวง จ. แม่ฮ่องสอน',
#  'เทศบาลตำบลกุดน้ำใส จ. ขอนแก่น',
#  'เทศบาลตำบลท่าพระ จ. ขอนแก่น',
#  'ศูนย์อนามัยที่ 7 ขอนแก่น',
#  'เทศบาลตำบลลำน้ำพอง จ. ขอนแก่น',
#  'รพ. สต. เก่างิ้ว จ. ขอนแก่น',
#  'โรงพยาบาลหนองเรือ จ. ขอนแก่น',
#  'องค์การบริหารส่วนตำบลเมืองเพีย จ. ขอนแก่น',
#  'รพ. สต. คำแก่นคูณ จ. ขอนแก่น',
#  'เทศบาลนครขอนแก่น',
#  'มหาวิทยาลัยขอนแก่น',
#  'โรงพยาบาลศรีบุญเรือง',
#  'สำนักงานสาธารณสุขจังหวัดร้อยเอ็ด',
#  'องค์การบริหารส่วนตำบลเหนือเมือง จ. ร้อยเอ็ด',
#  'เทศบาลตำบลโคกสูง จ. ร้อยเอ็ด',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลหนองบ้านหนองนาสร้าง จ. ร้อยเอ็ด',
#  'รพ.สต. บ้านสองห้อง อ. โพนทอง จ. ร้อยเอ็ด',
#  'โรงพยาบาลสุวรรณภูมิ จ. ร้อยเอ็ด',
#  'กองอำนวยการรักษาความมั่นคงภายในราชอาณาจักร (กอ.รมน.)',
#  'องค์การบริหารส่วนตำบลแก้งแก จ. มหาสารคาม',
#  'เทศบาลเมืองมหาสารคาม',
#  'สำนักงานสาธารณสุขอำเภอวาปีปทุม จ. มหาสารคาม',
#  'สำนักงานสาธารณสุขจังหวัดกาฬสินธุ์',
#  'สำนักงานสาธารณสุขอำเภอกมลาไสย',
#  'รพ. แม่ระมาด จ. ตาก',
#  'โรงพยาบาลสมเด็จพระยุพราชกุฉินารายณ์ จ. กาฬสินธุ์',
#  'สำนักวิชาเทคโนโลยีสารสนเทศ มหาวิทยาลัยแม่ฟ้าหลวง จ. เชียงราย',
#  'ศูนย์พัฒนาทักษะและการเรียนรู้ CIC ภูเก็ต',
#  'มหาวิทยาลัยสงขลานครินทร์ วิทยาเขตภูเก็ต',
#  'บจก. กี่หิ้นเวริ์คชอฟ',
#  'โรงพยาบาลกุมภวาปี จ. อุดรธานี',
#  'มหาวิทยาลัยมหิดล (ศาลายา)',
#  'มหาวิทยาลัยเทคโนโลยีราชมงคลล้านนา (ดอยสะเก็ด)',
#  'สำนักงานสาธารณสุขอำเภอสมเด็จ จ. กาฬสินธุ์',
#  'สำนักงานสาธารณสุขอำเภอเมืองกาฬสินธุ์',
#  'สำนักงานสาธารณสุขอำเภอกุฉินารายณ์ จ. กาฬสินธุ์',
#  'ศูนย์อนามัยที่ 8 อุดรธานี',
#  'สำนักงานสาธารณสุขจังหวัดอุดรธานี',
#  'โรงพยาบาลอุดรธานี',
#  'โรงพยาบาลหนองหาน จ. อุดรธานี',
#  'โรงพยาบาลบ้านผือ จ. อุดรธานี',
#  'สำนักงานสิ่งแวดล้อมภาคที่ 9 (อุดรธานี)',
#  'สำนักงานสาธารณสุขจังหวัดบึงกาฬ',
#  'โรงพยาบาลศรีวิไล จ. บึงกาฬ',
#  'วัดบัวบก อ.บ้านธิ จ.ลำพูน',
#  'โรงพยาบาลบึงโขงหลง จ. บึงกาฬ',
#  'โรงพยาบาลหนองคาย',
#  'โรงพยาบาลสมเด็จพระยุพราชท่าบ่อ จ. หนองคาย',
#  'สาธารณสุขจังหวัดหนองคาย',
#  'สสอ. โพนพิสัย จ. หนองคาย',
#  'โรงพยาบาลสมเด็จพระยุพราชด่านซ้าย จ. เลย',
#  'โรงพยาบาลวังสะพุง จ. เลย',
#  'โรงพยาบาลผาขาว จ. เลย',
#  'โรงพยาบาลปากชม จ. เลย',
#  'สำนักงานสาธารณสุขจังหวัดเลย',
#  'โรงพยาบาลสมเด็จพระยุพราชธาตุพนม จ. นครพนม',
#  'โรงพยาบาลนครพนม',
#  'รพ. สต. เวินพระบาท จ. นครพนม',
#  'สาธารณสุขจังหวัดหนองบัวลำภู',
#  'โรงพยาบาลนากลาง จ. หนองบัวลำภู',
#  'โรงพยาบาลพระอาจารย์แบน ธนากโร จ. สกลนคร',
#  'สำนักงานสาธารณสุขจังหวัดสกลนคร',
#  'โรงพยาบาลสกลนคร',
#  'มหาวิทยาลัยเกษตรศาสตร์ วิทยาเขตเฉลิมพระเกียรติ',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดสกลนคร',
#  'ศูนย์อนามัยที่ 9 นครราชสีมา',
#  'ศูนย์อนามัยที่ 10 อุบลราชธานี',
#  'โรงพยาบาลสำโรง จ. อุบลราชธานี',
#  'โรงพยาบาลสามเงา จ. ตาก',
#  'โรงพยาบาลวารินชําราบ จ. อุบลราชธานี',
#  'โรงพยาบาลสิรินธร จ. อุบลราชธานี',
#  'โรงพยาบาลสรรพสิทธิประสงค์ จ. อุบลราชธานี',
#  'โรงพยาบาลน้ำยืน จ. อุบลราชธานี',
#  'โรงพยาบาลสมเด็จพระยุพราชเดชอุดม จ. อุบลราชธานี',
#  'สำนักงานสาธารณสุขจังหวัดอุบลราชธานี',
#  'สำนักงานสาธารณสุขอำเภอพนา จังหวัดอำนาจเจริญ',
#  'สำนักงานสาธารณสุขจังหวัดอำนาจเจริญ',
#  'สำนักงานสาธารณสุขอำเภอสามชัย จ. กาฬสินธุ์',
#  'โรงพยาบาลกุดชุม จ. ยโสธร',
#  'โรงพยาบาลค้อวัง จ. ยโสธร',
#  'สนง. ป้องกันและบรรเทาสาธารณภัย จ. ยโสธร',
#  'สำนักงานสาธารณสุขจังหวัดพิษณุโลก',
#  'ถนนสุรนารี เทศบาลนครราชสีมา',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านนิคม ยโสธร',
#  'โรงพยาบาลมุกดาหาร',
#  'รพ.สต. บ้านดงเย็น จ. มุกดาหาร',
#  'สำนักงานสาธารณสุขจังหวัดศรีสะเกษ',
#  'โรงหมอเมืองไชยเซษฐา นครหลวงเวียงจันทน์',
#  'แผนกสาธารณสุขนคร เวียงจันทน์',
#  'โรงหมอเมืองนาทรายทอง เวียงจันทน์',
#  'โรงพยาบาลวานรนิวาส',
#  'รพ.สต. น้ำปลีก จ. อำนาจเจริญ',
#  'รพ.สต. โนนดู่ จ. อำนาจเจริญ',
#  'โรงพยาบาลมหาชนะชัย จ. ยโสธร',
#  'รพ.สต. โคกเจริญ จ. อำนาจเจริญ',
#  'รพ.สต. บ้านหนองแซง จ. กาฬสินธุ์',
#  'สสอ. สังคม จ. หนองคาย',
#  'สถานีอนามัยเฉลิมพระเกียรติ 60 พรรษา นวมินทราชินี เฝ้าไร่',
#  'โรงพยาบาลศรีเชียงใหม่ จ. หนองคาย',
#  'รพ.สต. โพนทอง จ. หนองคาย',
#  'รพ.สต. รัตนวาปี จ. หนองคาย',
#  'รพ.สต. สระใคร จ. หนองคาย',
#  'โรงพยาบาลปลาปาก จ. นครพนม',
#  'โรงพยาบาลสมเด็จพระยุพราชเลิงนกทา จ. ยโสธร',
#  'โรงพยาบาลไทยเจริญ จ. ยโสธร',
#  'โรงพยาบาลป่าติ้ว จ. ยโสธร',
#  'โรงพยาบาลบ้านแพง จ. นครพนม',
#  'สำนักงานเทศบาลนครนนทบุรี อาคาร 2 ',
#  'สำนักงานแขวงท่าทราย เทศบาลนครนนทบุรี ',
#  'ร้านขนมปัง Victory Bakery เทศบาลนครนนทบุรี',
#  'ศูนย์บริการสาธารณสุขที่ 2 เทศบาลนครนนทบุรี ',
#  'ศูนย์บริการสาธารณสุขที่ 4 (วัดสมรโกฏิ) เทศบาลนครนนทบุรี',
#  'ต.ชมพู อ.เมือง จ.ลำปาง',
#  'ต. หลวงเหนือ อ. งาว จ.ลำปาง',
#  'ต. ล้อมแรด อ. เถิน จ. ลำปาง',
#  'อุทยานดาราศาสตร์สิรินธร (สดร.) อ.แม่ริม จ.เชียงใหม่',
#  'สถาบันวิทยาศาสตร์สุขภาพ มหาวิทยาลัยเชียงใหม่',
#  'สนามกีฬากลาง มหาวิทยาลัยเชียงใหม่',
#  'ประตูหน้า มช. มหาวิทยาลัยเชียงใหม่',
#  'คณะมนุษยศาสตร์ มช. (อาคาร HB5)',
#  'อาคาร 40 ปี คณะวิทยาศาสตร์ มหาวิทยาลัยเชียงใหม่',
#  'อาคารกิจกรรมนักศึกษา (อมช.) มหาวิทยาลัยเชียงใหม่',
#  'คณะการสื่อสารมวลชน มหาวิทยาลัยเชียงใหม่',
#  'สำนักบริการวิชาการ  มหาวิทยาลัยเชียงใหม่ ',
#  'อาคารสุจิณโณ คณะแพทย์ศาสตร์ มหาวิทยาลัยเชียงใหม่',
#  'อาคารจอดรถสวนดอกปาร์ค มหาวิทยาลัยเชียงใหม่',
#  'ต. สวนดอก อ. เมือง จ. ลำปาง',
#  'โรงพยาบาลสามเงา\u200b จ.ตาก',
#  'ต. วิเชตนคร อ. แจ้ห่ม จ. ลำปาง ',
#  'รพสต. หนองกุลา อ. บางระกำ จ. พิษณุโลก',
#  'รพ.สต. ปลักแรด อ. บางระกำ จ. พิษณุโลก',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลบึงกอก',
#  'โรงพยาบาลบางระกำ จ. พิษณุโลก',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านชุมแสงสงคราม',
#  'คณะสังคมศาสตร์ มหาวิทยาลัยเชียงใหม่',
#  'โรงพยาบาลปากคาด จ. บึงกาฬ',
#  'โรงพยาบาลบุ่งคล้า จ. บึงกาฬ',
#  'โรงพยาบาลพรเจริญ จ. บึงกาฬ',
#  'โรงพยาบาลเซกา จ. บึงกาฬ',
#  'บ้านวัดจามเทวี จ. ลำพูน',
#  'เทศบาลตำบลวังดิน จ.ลำพูน',
#  'ศูนย์สุขภาพชุมชนลี้ จ.ลำพูน',
#  'รพ.นครปฐม',
#  'รพ.สต.อ้อมใหญ่ ',
#  'รพ.นครชัยศรี',
#  'คณะสิ่งแวดล้อมและทรัพยากรศาสตร์',
#  'คณะสาธารณสุขศาสตร์',
#  'คณะการบัญชีและการจัดการ มหาวิทยาลัยมหาสารคาม',
#  'โรงพยาบาลกู่แก้ว',
#  'รพ.สต. บ้านดงมะตื๋น (บ้านร่องห้า หมู่ 1)',
#  'รพ.สต. บ้านดงมะตื๋น (บ้านทุ่งยั้ง หมู่ 2)',
#  'โรงพยาบาลโซ่พิสัย',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดงมะตื๋น',
#  'รพ.สต. บ้านดงมะตื๋น (บ้านดงมะตื๋นใหม่ หมู่ 15)',
#  'โรงเรียนบ้านโชคเจริญ',
#  'รพ.สต.ผากลางนา',
#  'หอดูดาวเฉลิมพระเกียรติ 7 รอบ พระชนมพรรษา จ. สงขลา',
#  'วิทยาลัยอาชีวศึกษากาญจนบุรี',
#  'MV ลำปาง (บ้านผาลาด ตำบลพระบาท หมู่ 4)',
#  'ห้าแยกฉลอง จ.ภูเก็ต',
#  'กองทัพภาคที่ 1 (กอ.รมน. ภาค) ',
#  'ด่านตรวจกองกำลังบูรพา จ.สระแก้ว (กอ.รมน.ภาค 1 สย.1)',
#  'หน่วยเฉพาะกิจนาวิกโยธินตราด จ.ตราด (กอ.รมน.ภาค 1 สย.3)',
#  'ศาลาว่าการกรุงเทพมหานคร (กอ.รมน. กรุงเทพฯ)',
#  'ป้อมตำรวจ สี่แยกแคราย ถนนรัตนาธิเบศร์ (กอ.รมน. นนทบุรี)',
#  'ศูนย์ปฏิบัติการต่อต้านยาเสพติด จ.ปทุมธานี (กอ.รมน. ปทุมธานี)',
#  'อาคารอเนกประสงค์เทศบาลนครสมุทรปราการ (กอ.รมน. สมุทรปราการ)',
#  'ศาลากลางจังหวัดสมุทรสงคราม (กอ.รมน. สมุทรสงคราม)',
#  'สำนักงานเทศบาลเมืองกระทุ่มแบน (กอ.รมน. สมุทรสาคร)',
#  'ศาลากลางจังหวัดพระนครศรีอยุธยา (กอ.รมน. อยุธยา)',
#  'โรงพยาบาลค่ายอดิศร (กอ.รมน. สระบุรี)',
#  'ศาลากลางจังหวัดลพบุรี (กอ.รมน. ลพบุรี)',
#  'องค์การบริหารส่วนตำบลหัวไผ่ (กอ.รมน. อ่างทอง)',
#  'องค์การบริหารส่วนตำบลโพกรวม (กอ.รมน. สิงห์บุรี)',
#  'สถานีอุตุนิยมวิทยาชัยนาท (กอ.รมน. ชัยนาท)',
#  'ศาลากลางจังหวัดฉะเชิงเทรา (กอ.รมน. ฉะเชิงเทรา)',
#  'ศาลากลางจังหวัดนครนายก (กอ.รมน. นครนายก)',
#  'ฝูงบิน 206 วัฒนานคร (กอ.รมน. สระแก้ว)',
#  'สวนอุตสาหกรรมกบินทร์บุรี (กอ.รมน. ปราจีนบุรี)',
#  'ที่ว่าการอำเภอทองผาภูมิ (กอ.รมน. กาญจนบุรี)',
#  'สำนักงานสาธารณสุขอำเภอด่านช้าง (กอ.รมน. สุพรรณบุรี)',
#  'สำนักเทศบาลเมืองไร่ขิง (กอ.รมน. นครปฐม)',
#  'หน่วยป้องกันและรักษาป่าที่ รบ.3 พุยาง (กอ.รมน. ราชบุรี)',
#  'สํานักงานเทศบาลเมืองเพชรบุรี (กอ.รมน. เพชรบุรี)',
#  'สำนักงานเทศบาลเมืองหัวหิน (กอ.รมน. ประจวบคีรีขันธ์)',
#  'ที่ว่าการอําเภอบ้านบึง (กอ.รมน. ชลบุรี)',
#  'สำนักงานเทศบาลตำบลซำฆ้อ (กอ.รมน. ระยอง)',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดจันทบุรี (กอ.รมน. จันทบุรี)',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดตราด (กอ.รมน. ตราด)',
#  'สำนักงานเทศบาลนครหาดใหญ่',
#  'สำนักงานการวิจัยแห่งชาติ (วช.)',
#  'อู่ทหารเรือธนบุรี กรมอู่ทหารเรือ จุดที่ 1',
#  'อู่ทหารเรือธนบุรี กรมอู่ทหารเรือ จุดที่ 2',
#  'ลานประตูท่าแพ  (2)',
#  'ลานประตูท่าแพ  (1)',
#  'รพ. สันทราย จ. เชียงใหม่',
#  'เทศบาลเมืองสีคิ้ว จ. นครราชสีมา 1',
#  'เทศบาลเมืองสีคิ้ว จ. นครราชสีมา 2 ',
#  'สระว่ายน้ำ สนามกีฬา 700 ปี จ.เชียงใหม่',
#  'ค่ายพระยาสุนทรธรรมธาดา จ.อุดรธานี (กอ.รมน.ภาค 2 ส่วนแยก 1)',
#  'ค่ายวีรโยธิน กกล.สุรนารี จ.สุรินทร์ (บก.กอ.รมน.ภาค 2 ส่วนแยก 2)',
#  'หอประชุมเปรมติณสูลานนท์ จ.นครราชสีมา (กอ.รมน. นครราชสีมา)',
#  'ศาลากลางจังหวัดอุบลราชธานี (กอ.รมน. อุบลราชธานี)',
#  'ศาลากลางจังหวัดอำนาจเจริญ (กอ.รมน. อำนาจเจริญ)',
#  'ศาลากลางจังหวัดกาฬสินธุ์ (กอ.รมน. กาฬสินธุ์)',
#  'ศาลากลางจังหวัดบุรีรัมย์ (กอ.รมน. บุรีรัมย์)',
#  'ศาลากลางจังหวัดร้อยเอ็ด (กอ.รมน. ร้อยเอ็ด)',
#  'ศาลากลางจังหวัดยโสธร (กอ.รมน. ยโสธร)',
#  'ศาลากลางจังหวัดนครพนม หลังเก่า (กอ.รมน. นครพนม)',
#  'สถานีอุตุนิยมวิทยาสกลนคร (กอ.รมน. สกลนคร)',
#  'อาคาร บก.กอ.รมน.ภาค 3 จ.พิษณุโลก (บก.กอ.รมน.ภาค 3)',
#  'บก.ฉก.ม.4 ค่ายพิชิตปรีชากร อ.เชียงดาว จ.เชียงใหม่ (กอ.รมน.ภาค 3 สย.2)',
#  'ศาลากลางจังหวัดตาก (กอ.รมน. ตาก)',
#  'ที่ว่าการอำเภอแม่สอด (กอ.รมน. ตาก)',
#  'อบต.บ้านโป่ง อ.เวียงป่าเป้า จ.เชียงราย (กอ.รมน. เชียงราย)',
#  'อบต.ศรีถ้อย อ.แม่สรวย จ.เชียงราย (กอ.รมน. เชียงราย)',
#  'รพ.สต.เตาปูน อ.สอง จ.แพร่ (กอ.รมน. แพร่)',
#  'สถานีอนามัยไฮย้อย อ.วังชิ้น จ.แพร่ (กอ.รมน. แพร่)',
#  'อบต.บ้านมาง อ.เชียงม่วน จ.พะเยา (กอ.รมน. พะเยา)',
#  'หน่วยป้องกันรักษาป่าที่ พย.7 นาปรัง (กอ.รมน. พะเยา)',
#  'ที่ว่าการอำเภอลี้ จ.ลำพูน (กอ.รมน. ลำพูน)',
#  'ที่ว่าการอำเภอบ้านโฮ่ง จ.ลำพูน (กอ.รมน. ลำพูน)',
#  'สถานีวิทยุตำรวจภูธรภาค 6 จ.กำแพงเพชร (กอ.รมน. กำแพงเพชร)',
#  'ศาลากลางจังหวัดนครสวรรค์ หลังเก่า (กอ.รมน. นครสวรรค์)',
#  'ที่ว่าการอำเภอศรีสัชนาลัย (กอ.รมน. สุโขทัย)',
#  'ศาลากลางจังหวัดพิษณุโลก (กอ.รมน. พิษณุโลก)',
#  'ศาลากลางจังหวัดเพชรบูรณ์ อาคาร 1 (กอ.รมน. เพชรบูรณ์)',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดอุตรดิตถ์ (กอ.รมน. อุตรดิตถ์)',
#  'อาคารร้อยอาวุธเบาที่ 2 ร.25 พัน.2 จ.ระนอง (กอ.รมน.ภาค 4 สย.1)',
#  'ร.5 พัน.2 ค่ายมันตรัฐบุรินทร์ จ.สตูล (กอ.รมน. สตูล)',
#  'สำนักงานเทศบาลตำบลกำแพง อ.ละงู จ.สตูล (กอ.รมน. สตูล)',
#  'ศาลากลางจังหวัดสงขลา (กอ.รมน. สงขลา)',
#  'สำนักงาน กอ.รน.จังหวัดสงขลาส่วนหน้า อ.นาทวี (กอ.รมน. สงขลา)',
#  'หน่วยบริการประชาชนป้อมยามท่าเรือ สภ.ถลาง จ.ภูเก็ต (กอ.รมน. ภูเก็ต)',
#  'จุดบริการนักท่องเที่ยวหาดป่าตอง อ.กระทู้ จ.ภูเก็ต (กอ.รมน. ภูเก็ต)',
#  'ศาลากลางจังหวัดกระบี่ (กอ.รมน. กระบี่)',
#  'ศูนย์บริการนักท่องเที่ยว ในพื้นที่ศาลากลางจังหวัดพัทลุง (กอ.รมน. พัทลุง)',
#  'บก.ทภ.2 จ.นครราชสีมา (กอ.รมน.ภาค 2)',
#  'สำนักงาน กอ.รมน.จังหวัดชัยภูมิ (กอ.รมน.จังหวัดชัยภูมิ)',
#  'สำนักงานเขตพื้นที่การศึกษาประถมศึกษาขอนแก่นเขต 2 อ.บ้านไผ่ จ.ขอนแก่น (กอ.รมน.จังหวัดขอนแก่น)',
#  'ศาลากลางจังหวัดอุดรธานี (กอ.รมน.จังหวัดอุดรธานี)',
#  'ศาลากลางจังหวัดสุรินทร์ (กอ.รมน.จังหวัดสุรินทร์)',
#  'บก.ฉก.ร.4 บ.ห้วยหินฝน อ.แม่สอด จ.ตาก (กอ.รมน.ภาค 3 สย.1)',
#  'อาคาร กอ.รมน.ภาค 4 ค่ายวชิราวุธ (กอ.รมน.ภาค 4)',
#  'ศาลากลางจังหวัดบึงกาฬ (กอ.รมน.จังหวัดบึงกาฬ)',
#  'ศาลากลางจังหวัดหนองบัวลำภู (กอ.รมน. หนองบัวลำภู)',
#  'ศาลากลางจังหวัดแม่ฮ่องสอน (กอ.รมน. แม่ฮ่องสอน)',
#  'วัดพระธาตุดอยกองมู อ.เมืองแม่ฮ่องสอน (กอ.รมน. แม่ฮ่องสอน)',
#  'สถานีอุตุนิยมวิทยาอุทัยธานี ต.น้ำซึม อ.เมืองอุทัยธานี (กอ.รมน. อุทัยธานี)',
#  'วัดท่าหลวง (บริเวณแม่น้ำน่าน) อ.เมืองพิจิตร (กอ.รมน. พิจิตร)',
#  'ดาดฟ้า กอ.รมน. ปัตตานี ต.สะบารัง อ.เมืองปัตตานี (กอ.รมน. ปัตตานี)',
#  'ดาดฟ้า มทบ.46 ต.บ่อทอง อ.หนองจิก (กอ.รมน. ปัตตานี)',
#  'ศาลากลางจังหวัดมหาสารคาม (กอ.รมน.มหาสารคาม)',
#  'สำนักงานเทศบาลเมืองยโสธร',
#  'สวนสาธารณะเฉลิมพระเกียรติ (วิมานพญาแถน)',
#  'สวนสาธารณะพญาแถน',
#  'สวนสาธารณะบุ่งน้อยบุ่งใหญ่',
#  'บ.หนองบัว ต.เชิงดอย อ.ดอยสะเก็ด จ.เชียงใหม่',
#  'รร.บ้านปางเฟือง จ.เชียงใหม่',
#  'รร.มิตรมวลชน จ.เชียงใหม่',
#  'บ้านหัวโท หมู่ที่ 6 ต.ปิงโค้ง อ.เชียงดาว จ.เชียงใหม่',
#  'รร.บ้านห้วยจะค่าน จ.เชียงใหม่',
#  'รร.บ้านรินหลวง จ.เชียงใหม่',
#  'รร.บ้านออน จ.เชียงใหม่',
#  'รพ.สต.บ้านแม่นะ จ.เชียงใหม่',
#  'รพ.สต.บ้านใหม่ จ.เชียงใหม่',
#  'รพ.น้ำหนาว จ.เพชรบูรณ์',
#  'รพ.หล่มสัก จ.เพชรบูรณ์',
#  'รพ.วังโป่ง จ.เพชรบูรณ์',
#  'อบต.เกาะหมาก จ.ตราด',
#  'รพ.สต.บ้านปงตำ จ.เชียงใหม่',
#  'อาคารผู้ป่วยนอก รพ.นาแก จ.นครพนม',
#  'รพ.สต.ค่ายสว่าง จ.หนองบัวลำภู',
#  'ทม.ศรีสัชนาลัย (หลังใหม่) จ.สุโขทัย',
#  'ตลาดสด ทต.ย่านดินแดง จ.สุราษฎร์ธานี',
#  'วัดย่านดินแดง จ.สุราษฎร์ธานี',
#  'รพ.วัดโบสถ์ จ.พิษณุโลก',
#  'รพ.พรหมพิราม จ.พิษณุโลก',
#  'รพ. เชียงรายประชานุเคราะห์ จ. เชียงราย',
#  'รพ. ปางมะผ้า จ. แม่ฮ่องสอน',
#  'รพ. ขุนยวม จ. แม่ฮ่องสอน',
#  'มหาวิทยาลัยเชียงใหม่ แคมปัสแม่เหียะ',
#  'กระทรวงสาธารณสุข  ',
#  'โรงเรียนบ้านคุณแม่ อ. หางดง จ. เชียงใหม่',
#  'นันทชาติ พรีสคูล จ. เชียงใหม่',
#  'ศาลากลางจังหวัดกำแพงเพชร',
#  'ที่ว่าการอำเภอเมืองกำแพงเพชร',
#  'ห้องสมุดองครักษ์ มหาวิทยาลัยศรีนครินทรวิโรฒ องครักษ์  นครนายก',
#  'สำนักงานเทศบาลตำบลเทพนคร อ.เมืองกำแพงเพชร',
#  'สำนักหอสมุดกลาง มหาวิทยาลัยศรีนครินทรวิโรฒ',
#  'สำนักงาน อบต.สระแก้ว อ. เมือง จ. กำแพงเพชร',
#  'สำนักงาน อบต. ทรงธรรม อ.เมือง จ. กำแพงเพชร',
#  'สถานีตรวจวัดคุณภาพอากาศ กรมควบคุมมลพิษ อ. เมือง จ. อุบลราชธานี 1',
#  'โรงเรียนวัดนาคปรก กรุงเทพฯ',
#  'โรงเรียนอนุบาลทอฟ้า กรุงเทพฯ',
#  'โรงเรียนมหรรณพาราม กรุงเทพฯ',
#  'โรงเรียนวัดบางประทุนนอก กรุงเทพฯ',
#  'โรงเรียนปัญญาวิทยา กรุงเทพฯ',
#  'โรงเรียนเลิศหล้ากาญจนาภิเษก กรุงเทพฯ',
#  'โรงเรียนวัดลาดปลาเค้า กรุงเทพฯ',
#  'โรงเรีนนคลองสองต้นนุ่น กรุงเทพฯ',
#  'สถานีตรวจวัดคุณภาพอากาศ กรมควบคุมมลพิษ อ. เมือง จ. อุบลราชธานี 2',
#  'สถานีตรวจวัดคุณภาพอากาศกรมควบคุมมลพิษ อ. เมือง จ. อุบลราชธานี 3',
#  'อาคารบางกอกแลนด์ เมืองทองธานี',
#  'โรงเรียนเทศบาล3 (ตลาดล่าง)\u200b',
#  'โรงเรียนเทศบาล5 (เทศบาลสุราษฎร์ธานี)\u200b',
#  'สำนักงานเทศบาลนครสุราษฎร์ธานี',
#  'ศูนย์บริการสาธารณสุขเทศบาลนครสุราษฎร์ธานี (ศูนย์ตาปี)\u200b',
#  'พระตำหนักภูพิงคราชนิเวศน์ ',
#  'หมู่บ้านชวนชื่นนีโอเฮาส์ แขวงรามอินทรา เขตคันนายาว กรุงเทพฯ',
#  'อบต. บ้านมาง อ. เชียงม่วน จ. พะเยา',
#  'สำนักงานสาธารณสุข จ. พะเยา',
#  'รพ. ปาย จ. แม่ฮ่องสอน',
#  'รพ. แม่สะเรียง จ. แม่ฮ่องสอน',
#  'รพ. สบเมย จ. แม่ฮ่องสอน',
#  'รพ. บ้านหลวง จ. น่าน',
#  'หอการค้าเชียงใหม่ จ. เชียงใหม่',
#  'รพ. นาหมื่น จ. น่าน',
#  'ทต. ปัว จ. น่าน',
#  'โรงพยาบาลแม่สาย จ. เชียงราย',
#  'สำนักงานสาธารณสุขจังหวัดเชียงราย',
#  'รพ.สต. อรุโณทัย ต. เมืองนะ จ. เชียงใหม่',
#  'รพ.สต. บ้านแม่แฮเหนือ จ. เชียงใหม่',
#  'รพ.สต. แม่ซา จ. เชียงใหม่',
#  'กรีนพีซประเทศไทย กรุงเทพฯ',
#  'รพ.สต. บ้านปางมะเยา จ. เชียงใหม่',
#  'รพ.สต. แม่นาจร จ. เชียงใหม่',
#  'ทต. ปิงโค้ง จ. เชียงใหม่',
#  'ทต. เมืองนะ จ. เชียงใหม่',
#  'รพ.สต. เกาะช้าง จ. เชียงราย',
#  'เทศบาลตำบลพิชัย จ. ลำปาง',
#  'รพ. พร้าว จ. เชียงใหม่',
#  'สำนักวิชาเทคโนโลยีสารสนเทศ อาคาร E3A-Building',
#  'รร. ยุพราชวิทยาลัย จ. เชียงใหม่',
#  'ม. สุขภาพ ลาว 1',
#  'ม. สุขภาพ ลาว 2',
#  'มูลนิธิน้ำโขง-ตองยี พม่า',
#  'องค์การบริหารส่วนตำบลบ่อเกลือเหนือ',
#  'เทศบาลตำบลบ่อแก้ว',
#  'องค์การบริหารส่วนตำบลเจดีย์ชัย',
#  'องค์การบริหารส่วนตำบลไชยสถาน',
#  'องค์การบริหารส่วนตำบลป่าคา',
#  'องค์การบริหารส่วนตำบลพระธาตุ',
#  'องค์การบริหารส่วนตำบลแงง',
#  'องค์การบริหารส่วนตำบลชนแดน',
#  'องค์การบริหารส่วนตำบลปิงหลวง',
#  'เทศบาลตำบลงอบ',
#  'เทศบาลตำบลยอด',
#  'องค์การบริหารส่วนตำบลเปือ',
#  'องค์การบริหารส่วนตำบลนาไร่หลวง',
#  'เทศบาลตำบลพระพุทธบาท',
#  'องค์การบริหารส่วนตำบลห้วยโก๋น',
#  'เทศบาลตำบลเชียงกลาง',
#  'องค์การบริหารส่วนตำบลขุนน่าน',
#  'องค์การบริหารส่วนตำบลสถาน',
#  'องค์การบริหารส่วนตำบลทุ่งช้าง',
#  'เทศบาลตำบลทุ่งช้าง',
#  'เทศบาลตำบลท่าวังผา',
#  'องค์การบริหารส่วนตำบลเมืองลี',
#  'องค์การบริหารส่วนตำบลและ',
#  'องค์การบริหารส่วนตำบลปอน',
#  'องค์การบริหารส่วนตำบลน้ำตก',
#  'องค์การบริหารส่วนตำบลนาปัง',
#  'องค์การบริหารส่วนตำบลแม่ขะนิง',
#  'องค์การบริหารส่วนตำบลศรีภูมิ',
#  'องค์การบริหารส่วนตำบลตาลชุม',
#  'องค์การบริหารส่วนตำบลทุ่งศรีทอง',
#  'เทศบาลตำบลเวียงสา',
#  'องค์การบริหารส่วนตำบลน้ำแก่น',
#  'องค์การบริหารส่วนตำบลผาตอ',
#  'เทศบาลตำบลหนองแดง',
#  'องค์การบริหารส่วนตำบลดงพญา',
#  'เทศบาลตำบลกลางเวียง',
#  'เทศบาลตำบลขึ่ง',
#  'องค์การบริหารส่วนตำบลเมืองจัง',
#  'องค์การบริหารส่วนตำบลจอมจันทร์',
#  'องค์การบริหารส่วนตำบลส้าน',
#  'อบต.ยม',
#  'องค์การบริหารส่วนตำบลแสนทอง',
#  'องค์การบริหารส่วนตำบลสวก',
#  'องค์การบริหารส่วนตำบลไหล่น่าน',
#  'องค์การบริหารส่วนตำบลหนองแดง',
#  'องค์การบริหารส่วนตำบลจอมพระ',
#  'องค์การบริหารส่วนตำบลน้ำมวบ',
#  'องค์การบริหารส่วนตำบลยาบหัวนา',
#  'องค์การบริหารส่วนตำบลบ้านฟ้า',
#  'องค์การบริหารส่วนตำบลภูฟ้า',
#  'องค์การบริหารส่วนตำบลผาทอง',
#  'เทศบาลตำบลศิลาแลง',
#  'องค์การบริหารส่วนตำบลแม่สาคร',
#  'องค์การบริหารส่วนตำบลแม่สา',
#  'เทศบาลตำบลศรีษะเกษ',
#  'องค์การบริหารส่วนตำบลน้ำพาง',
#  'องค์การบริหารส่วนตำบลริม',
#  'องค์การบริหารส่วนตำบลตาลชุม',
#  'องค์การบริหารส่วนตำบลแม่จริม',
#  'องค์การบริหารส่วนตำบลฝายแก้ว',
#  'องค์การบริหารส่วนตำบลวรนคร',
#  'องค์การบริหารส่วนตำบลผาสิงห์',
#  'องค์การบริหารส่วนตำบลป่าคาหลวง',
#  'องค์การบริหารส่วนจังหวัดน่าน',
#  'องค์การบริหารส่วนตำบลป่าแลวหลวง',
#  'องค์การบริหารส่วนตำบลสะเนียน',
#  'เทศบาลเมืองน่าน',
#  'องค์การบริหารส่วนตำบลน้ำปั้ว',
#  'องค์การบริหารส่วนตำบลนาเหลือง',
#  'องค์การบริหารส่วนตำบลนาน้อย',
#  'เทศบาลตำบลกองควาย',
#  'องค์การบริหารส่วนตำบลสันทะ',
#  'เทศบาลตำบลดู่ใต้',
#  'องค์การบริหารส่วนตำบลดุ่พงษ์',
#  'องค์การบริหารส่วนตำบลนาซาว',
#  'องค์การบริหารส่วนตำบลสกาด',
#  'องค์การบริหารส่วนตำบลถืมตอง',
#  'องค์การบริหารส่วนตำบลสถาน',
#  'องค์การบริหารส่วนตำบลท่าน้าว',
#  'องค์การบริหารส่วนตำบลบ้านพี้',
#  'องค์การบริหารส่วนตำบลบ่อ',
#  'องค์การบริหารส่วนตำบลม่วงตึ๊ด',
#  'องค์การบริหารส่วนตำบลอ่ายนาไลย',
#  'องค์การบริหารส่วนตำบลพงษ์',
#  'องค์การบริหารส่วนตำบลสวด',
#  'องค์การบริหารส่วนตำบลป่ากลาง',
#  'องค์การบริหารส่วนตำบลเรือง',
#  'องค์การบริหารส่วนตำบลน้ำเกี้ยน',
#  'เทศบาลตำบลปัว',
#  'องค์การบริหารส่วนตำบลไชยวัฒนา',
#  'เทศบาลตำบลนาน้อย',
#  'องค์การบริหารส่วนตำบลบัวใหญ่',
#  'องค์การบริหารส่วนตำบลภูคา',
#  'องค์การบริหารส่วนตำบลเชียงของ',
#  'Resident House (RS)',
#  'สยามกิตติ์',
#  'จัตุรัสจามจุรี Office',
#  'บริเวณสวนในสยาม (Park@Siam)',
#  'บริเวณทางเดินภายในอาคาร Siam Square One',
#  'จัตุรัสจามจุรี Residence',
#  'อุทยาน 100 ปี จุฬาลงกรณ์มหาวิทยาลัย',
#  'มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา',
#  'ริมถนนทางหลวงหมายเลข 3902 ',
#  'กรมอุตุนิยมวิทยาบางนา',
#  'ศูนย์ฟื้นฟูอาชีพคนพิการและทุพลภาพ ',
#  'เคหะชุมชนคลองจั่น',
#  'การเคหะชุมชนห้วยขวาง ',
#  'โรงเรียนนนทรีวิทยา ',
#  'กรมควบคุมโรค',
#  'แขวงการทางสมุทรสาคร ',
#  'โรงไฟฟ้าพระนครใต้ ',
#  'บ้านพักกรมอุตสาหกรรมพื้นฐานและการเหมืองแร่',
#  'ศาลากลางจังหวัดสมุทรปราการ ',
#  'การเคหะชุมชนเมืองใหม่บางพลี ',
#  'มหาวิทยาลัยกรุงเทพ วิทยาเขตรังสิต ',
#  'โรงเรียนอยุธยาวิทยาลัย',
#  'มหาวิทยาลัยสุโขทัยธรรมาธิราช ',
#  'สถานีตำรวจภูธรตำบลหน้าพระลาน ',
#  'สถานีดับเพลิงพระลักษณ์',
#  'สำนักงานสิ่งแวดล้อมภาคที่8',
#  'โรงเรียนสมุทรสาครวิทยาลัย',
#  'สำนักงานสาธารณสุขอำเภอปลวกแดง',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลมาบตาพุด ',
#  'สำนักงานเกษตรจังหวัดระยอง ',
#  'ศูนย์วิจัยพืชไร่ระยอง ',
#  'สนามกีฬาเทศบาลแหลมฉบัง ',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเขาหิน',
#  'สำนักงานสิ่งแวดล้อมภาคที่ 13 ',
#  'ศูนย์ราชการจังหวัดเชียงใหม่ ',
#  'โรงเรียนยุพราชวิทยาลัย ',
#  'สถานีอุตุนิยมวิทยาลำปาง',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านสบป้าด ',
#  'โรงพยาบาลส่งเสริมสุขภาพตำบลท่าสี ',
#  'การประปาส่วนภูมิภาคแม่เมาะ',
#  'โครงการชลประทานนครสวรรค์',
#  'สำนักงานสิ่งแวดล้อมภาคที่ 14',
#  'ศูนย์บริการสาธารณสุขเทศบาลภูเก็ต',
#  'เทศบาลนครหาดใหญ่ ',
#  'ส่วนอุทกวิทยา สำนักงานทรัพยากรน้ำภาคที่4 ขอนแก่น',
#  'สถานีสูบน้ำประตูพลแสน',
#  'โรงพยาบาลจุฬาลงกรณ์',
#  'การไฟฟ้าย่อยธนบุรี ',
#  'สถานีตำรวจนครบาลโชคชัย ',
#  'การเคหะชุมชนดินแดง ',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดเชียงราย',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดแม่ฮ่องสอน',
#  'กรมประชาสัมพันธ์',
#  'สำนักงานเทศบาลตำบลทุ่งสะเดา',
#  'โรงเรียนบดินทรเดชา (สิงห์ สิงหเสนี) ',
#  'ศาลากลางจังหวัดนราธิวาส ',
#  'สนามโรงพิธีช้างเผือก ',
#  'สำนักงานเทศบาลเมืองน่าน',
#  'อุตุนิยมวิทยาลำพูน',
#  'อุตุนิยมวิทยาจังหวัดแพร่',
#  'สนามกีฬาจังหวัดพะเยา',
#  'สวนกาญจนาภิเษก ร.9 (ฝั่งสวนหิน)',
#  'สำนักงานสาธารณสุขจังหวัดเลย',
#  'สำนักงานสาธารณสุขแม่สาย',
#  'ศูนย์ราชการจังหวัดระยอง ',
#  'โรงพยาบาลเฉลิมพระเกียรติ ',
#  'ศูนย์การศึกษานอกโรงเรียน',
#  'ศาลาประชาคมบ้านบุยายใบ',
#  'ศูนย์พัฒนาเด็กเล็กเทศบาลเมืองเบตง',
#  'สถานีอุตุนิยมวิทยา จ.กาญจนบุรี',
#  'ศาลากลาง จ.สตูล',
#  'อ่างเก็บน้ำประปา',
#  'สวนสาธารณะหนองถิ่น',
#  'ศูนย์แสดงและจำหน่ายสินค้า OTOP จังหวัดอุบลราชธานี',
#  'สำนักงานสาธารณสุขจังหวัดสมุทรสงคราม',
#  'สนามกีฬากลางจังหวัดสุพรรณบุรี',
#  'สวนชมน่านเฉลิมพระเกียรติ',
#  'สนามกีฬากลางจังหวัดตราด',
#  'สถานีอุตุนิยมวิทยานครพนม',
#  'ศูนย์ฟื้นฟูสุขภาพผู้สูงอายุ',
#  'สถานีอุตุนิยมวิทยาสกลนคร',
#  'สวนสาธารณะหนองประจักษ์ อุดรธานี',
#  'สวนมหามงคลเฉลิมพระชนมพรรษา 6 รอบ 5 ธันวาคม 2552 อุตรดิตถ์',
#  'วิทยาลัยสารพัดช่างตรัง',
#  'สำนักงานเขตบึงกุ่ม',
#  'สำนักงานเขตคลองสามวา',
#  'สำนักงานเขตจอมทอง',
#  'สำนักงานเขตบางพลัด',
#  'สำนักงานเขตบางแค',
#  'สำนักงานเขตบางขุนเทียน',
#  'สำนักงานเขตดินแดง กรุงเทพฯ',
#  'สำนักงานเขตพระโขนง กรุงเทพฯ',
#  'สำนักงานเขตราษฎร์บูรณะ กรุงเทพฯ',
#  'สำนักงานเขตราชเทวี กรุงเทพฯ',
#  'ริมสวนหย่อมตรงข้ามสำนักงานเขตดุสิต',
#  'สำนักงานคณะกรรมการพัฒนาเศรษฐกิจและสังคมแห่งชาติ',
#  'วงเวียนโอเดียน',
#  'แฟลตทหารบก สามเสน',
#  'สำนักงานเขตวังทองหลาง',
#  'สามย่านมิตรทาวน์',
#  'ลานบางรักเลิฟลี่ พลาซ่า',
#  'สำนักงานเขตสาทร',
#  'สี่แยกถนนตก',
#  'ธนาคารกรุงศรีอยุธยา สำนักงานใหญ่',
#  'ริมถนนซอยสุขุมวิท 63',
#  'สำนักงานเขตสวนหลวง',
#  'บิ๊กซี ซุปเปอร์เซ็นเตอร์ บางนา',
#  'มหาวิทยาลัยเกษตรศาสตร์',
#  'สำนักงานเขตดอนเมือง',
#  'สำนักงานเขตสายไหม',
#  'สำนักงานเขตบางกะปิ',
#  'แยกสวนสยาม-รามอินทรา',
#  'โรงพยาบาลลาดกระบัง',
#  'สวนเฉลิมพระเกียรติ ร.9',
#  'สำนักงานเขตหนองจอก',
#  'ซีคอน สแควร์',
#  'แยกมไหศวรรย์',
#  'ห้องสมุดใต้สะพานสมเด็จพระเจ้าตากสิน',
#  'สี่แยกท่าพระ',
#  'สถานีตำรวจรถไฟบางกอกน้อย',
#  'ถนนพุทธมณฑลสาย 1 ตัดกับถนนบรมราชชนนี',
#  'ตลาดธนบุรีสนามหลวง 2',
#  'มหาวิทยาลัยสยาม',
#  'ริมถนนมาเจริญ เพชรเกษม 8, เขตหนองแขม',
#  'ตลาดบางบอน 5',
#  'มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าธนบุรี',
#  'สำนักงานเขตพระนคร',
#  'สำนักงานเขตห้วยขวาง',
#  'สำนักงานเขตคลองเตย',
#  'สำนักงานเขตบางซื่อ',
#  'สำนักงานเขตลาดพร้าว',
#  'สำนักงานเขตหลักสี่',
#  'สำนักงานเขตบางเขน',
#  'สำนักงานเขตสะพานสูง',
#  'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดสกลนคร',
#  'ค่ายสุรสิงหนาท',
#  'วัดอัมพวันหรือวัดบ้านหนองม่วง',
#  ' ที่ว่าการอำเภอเมืองกำแพงเพชร',
#  'ศูนย์ราชการจังหวัดบุรีรัมย์',
#  'ศาลากลางจังหวัดชัยภูมิ',
#  'ศูนย์ราชการจังหวัดกาฬสินธ์ุ',
#  'ศาลากลางจ.อุทัยธานี',
#  'ศูนย์ราชการจังหวัดพิจิตร',
#  'สวนศรีนครเขื่อนขันธ์',
#  'สำนักงานเทศบาลเมืองสุโขทัยธานี',
#  'สำนักงานเทศบาลเมืองอุตรดิตถ์',
#  'พระตำหนักภูพิงคราชนิเวศน์ ',
#  'ที่ว่าการอำเภอแม่แจ่ม',
#  'บ้านพักผู้ว่าราชการจังหวัดเพชรบูรณ์(หลังเก่า)',
#  'สถานีอุตุนิยมวิทยาลพบุรี',
#  'โครงการป่าวังจันทร์',
#  'โครงการป่าในกรุง',
#  'สำนักงานใหญ่ ปตท.',
#  'ตึก 3 คณะวิศวกรรมศาสตร์ จุฬาลงกรณ์มหาวิทยาลัย',
#  '(3) อาคาร 8 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'สำนักงานอุตสาหกรรมจังหวัดสุรินทร์',
#  'โรงเรียนคลองพานทอง',
#  'ห้างหุ้นส่วนจำกัดนพผดุงบริการ (มุกดาหาร)',
#  'อาคารสำนักงานใหญ่ บริษัท สหเรือง จำกัด',
#  'โรงพยาบาลแจ้ห่ม',
#  'ศูนย์พัฒนาเด็กเล็ก ตำบลบางผึ้ง',
#  '(13) อาคาร 47 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'โรงเรียนบ้านนนท์',
#  '(15) อาคาร 57 โครงการบ้านเอื้ออาทรบางโฉลง',
#  '(12) อาคารสำนักงาน เคหะชุมชนบางโฉลง',
#  'ศูนย์ศึกษาการพัฒนาห้วยฮ่องไคร้ จ.เชียงใหม่',
#  '(9) อาคาร 17 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'ป้ายวัดคุณภาพอากาศ การเคหะแห่งชาติบางโฉลง',
#  'ซอยเพชรเกษม 43 บางแค',
#  '(14) อาคาร 56 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'เขาค้อ วินด์ พาวเวอร์',
#  'โรงเรียนอนุบาลเพชรบูรณ์',
#  'โรงเรียนบรรจงรัตน์',
#  'เทศบาลตำบลเวียงสา',
#  'สำนักงานเคหะจังหวัดนนทบุรี สาขา1 (โครงการบ้านเอื้ออาทรนนทบุรี) การเคหะแห่งชาติ',
#  'สำนักงานเคหะนครหลวงสาขารามคำแหง (โครงการเคหะชุมชนรามคำแหง) การเคหะแห่งชาติ',
#  'โรงไฟฟ้าเขื่อนแก่งกระจาน',
#  'สันเขื่อนภูมิพล',
#  'รพ.สต.วัดโชติการาม',
#  'เขื่อนแม่งัดสมบูรณ์ชล',
#  'ศูนย์การเรียนรู้ กฟผ. แม่ออน',
#  'สำนักงานเคหะจังหวัดนครปฐม สาขา1 (โครงการบ้านเอื้ออาทรนครชัยศรี(ท่าตำหนัก)) การเคหะแห่งชาติ',
#  '(19) อาคาร 71 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'โรงเรียนแม่สะเรียง "บริพัตรศึกษา"',
#  'ตลาดสดเทศบาล 1 ตำบลเมืองเหนือ',
#  'สำนักงานนครราชสีมา การไฟฟ้าฝ่ายผลิตแห่งประเทศไทย',
#  'สำนักงานพลังงานจังหวัดนครราชสีมา',
#  'สำนักงานเทศบาลตำบลนิคมปราสาท',
#  'โรงเรียนอนุบาลมุกดาหาร',
#  'อาคารอานันทมหิดล คณะแพทยศาสตร์ จุฬาลงกรณ์มหาวิทยาลัย',
#  '(6) อาคาร 35 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'โรงเรียนมัธยมพัชรกิติยาภา ๑ นครพนม',
#  'แยกราชประสงค์ (หน้าทางเข้าศูนย์การค้าเซ็นทรัลเวิลด์)',
#  'โรงเรียนหล่มเก่าพิทยาคม',
#  'กฟผ. สำนักงานไทรน้อย',
#  '(18) อาคาร 74 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'เรือนน้ำพรม เขื่อนจุฬาภรณ์',
#  'สวนพฤกษศาสตร์ทวีชล',
#  'ศาลากลางน้ำ เขื่อนท่าทุ่งนา',
#  'โรงเรียนโรซารีโอวิทยา',
#  'วัดพระธาตุพนมวรมหาวิหาร',
#  'บริษัท มิตรผล ไบโอ-เพาเวอร์ จำกัด',
#  'โรงไฟฟ้าบางปะกง',
#  'โรงเรียนท่าปลาประชาอุทิศ',
#  'เขื่อนบางลาง',
#  'สี่แยกตลาดสดเทศบาลเมืองบุรีรัมย์ (ถนนสุนทรเทพ)',
#  'โรงเรียนบ้านทุ่งสาคร',
#  'สนามกีฬาจังหวัดพิจิตร',
#  'โรงเรียนกันทรลักษ์วิทยา',
#  'โรงเรียนเบ็ญจะมะมหาราช',
#  'โรงไฟฟ้าหนองระเวียง 1,2 (Gulf NRV1,2)',
#  'โรงเรียนส่วนบุญโญปถัมภ์',
#  'หจก.จอมพระปิโตรเลียม',
#  '(10) อาคาร 27 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'สำนักงานเคหะนครหลวง สาขาร่มเกล้า2 การเคหะแห่งชาติ',
#  'โรงเรียนวัดบางแสม',
#  'สถานีสูบน้ำหนองแค โรงไฟฟ้าวังน้อย',
#  'โรงเรียนวัดบางฝ้าย',
#  'อาคารอินเทค สันเขื่อนรัชชประภา',
#  'โรงเรียนมัธยมสิริวัณวรี ๓ ฉะเชิงเทรา',
#  'ตำบลไร่ขิง อำเภอสามพราน (ทีพีบีไอ)',
#  'โรงเรียนอนุบาลวัดสระแก้ว',
#  'โรงเรียนบางละมุง',
#  'โรงเรียนศรีสงครามวิทยา',
#  'วัดบำรุงธรรมราษฎร์ศรัทธาราม (วัดล่าง)',
#  'โรงไฟฟ้าดีเซลผาบ่อง',
#  'โรงเรียนวัดบางหัวเสือ',
#  'โรงเรียนบ้านสันติคีรี',
#  'โรงไฟฟ้ากระบี่',
#  'เขื่อนน้ำพุง',
#  'อาคารพลับพลา สันเขื่อนศรีนครินทร์',
#  'โรงเรียนวัดสว่างอารมณ์',
#  'โรงเรียนอนุบาลชัยภูมิ',
#  'ปตท. บ้านกลาง',
#  'สำนักงานเทศบาลตำบลท่าข้าม',
#  'โรงพยาบาลส่งเสริมสุขภาพ ตำบลหนองโรง',
#  'วัดควนมิตร',
#  'ปตท. ประตูโขง',
#  'ศูนย์ส่งเสริมอุตสาหกรรมภาคที่ 3',
#  'โรงเรียนเชียงของวิทยาคม',
#  'สุชาติแก๊ส อ.เมือง',
#  'โรงเรียนบ้านไผ่',
#  'โรงเรียนระยองวิทยาคม',
#  'โรงเรียนเมืองอำนาจเจริญ',
#  'โรงเรียนชุมแพศึกษา ขอนแก่น',
#  'ปตท. แม่ริม',
#  'สำนักงานพลังงานจังหวัดเพชรบูรณ์',
#  'โรงเรียนประสาทวิทยาคาร',
#  'ห้างหุ้นส่วนจำกัด ศรีบุญเรืองบริการ ปิโตรเลียม',
#  'องค์การบริหารส่วนตำบลม่วงเจ็ดต้น',
#  'ศาลพระยาพิชัย',
#  'แยกปทุมวัน',
#  'องค์การบริหารส่วนตำบลดงเสือเหลือง',
#  'สาธารณสุขจังหวัดหนองบัวลำภู',
#  'โรงเรียนหิรัญพงษ์อนุสรณ์',
#  'สันเขื่อนวชิราลงกรณ',
#  'โรงพยาบาลแม่พริก',
#  'เขตรักษาพันธุ์สัตว์ป่าบุณฑริก-ยอดมน',
#  'มัสยิดปากีสถาน พิษณุโลก',
#  '(8) อาคาร 92 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'โรงไฟฟ้าร้อยเอ็ดกรีน',
#  'องค์การบริหารส่วนตำบลต้าผามอก',
#  'เทศบาลตำบลเมืองเก่า',
#  'สำนักงานเทศบาลตำบลบ่อเกลือใต้',
#  'ปั๊มน้ำมันคาลเท็กซ์ (ช.วิบูลย์)',
#  'ปตท.ศรีบุญเรือง',
#  'โรงเรียนสารคามพิทยาคม',
#  'โรงเรียนตากพิทยาคม',
#  'โรงเรียนอนุบาลพิษณุโลก',
#  '(17) อาคาร 79 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'ศูนย์การเรียนรู้ กฟผ. สำนักงานกลาง',
#  'เขตรักษาพันธุ์สัตว์ป่ายอดโดม',
#  'โรงเรียนราชปิโยรสา ยุพราชานุสรณ์',
#  '(2) อาคาร 6 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'โรงเรียนพะเยาพิทยาคม',
#  'บมจ. ทีพีบีไอ (สาขาระยอง)',
#  'เทศบาลท่าบ่อ',
#  'โรงเรียนบ้านคำบอนคุรุราษฏร์บำรุง',
#  'โรงไฟฟ้าบ้านขุนกลาง',
#  'สำนักงานเคหะจังหวัดปทุมธานี 3 (โครงการบ้านเอื้ออาทรลาดหลุมแก้ว 2) การเคหะแห่งชาติ',
#  'โรงเรียนอนุบาลแม่ฮ่องสอน',
#  '(4) อาคาร 11 โครงการบ้านเอื้ออาทรบางโฉลง',
#  'โรงเรียนวัดบางด้วน',
#  'โรงเรียนมัธยมพัชรกิติยาภา 2',
#  'โรงเรียนวัดจุฬาจินดาราม',
#  'โรงเรียนอนุบาลอุดรธานี',
#  'โรงเรียนเทศบาลคำใหญ่ปันน้ำใจ',
#  'หอสมุดคณะแพทยศาสตร์ จุฬาลงกรณ์มหาวิทยาลัย',
#  'วัดทุ่งพระ',
#  'สวนสาธารณะเฉลิมพระเกียรติห้วยน้ำคำ (เกาะกลางน้ำ)',
#  ...]

# %%
Lat = []
for i in sen:
  lat = all_station[i]['lat']
  Lat.append(lat)

# %%
Lon = []
for i in sen:
  lon = all_station[i]['lon']
  Lon.append(lon)

# %%
Prov = []
for i in sen:
  prov = all_station[i]['province']
  Prov.append(prov)

# %%
Prov
# Out:
# ['กรุงเทพ',
#  'Phnom Penh',
#  'ศรีสะเกษ',
#  'Phnom Penh',
#  'Phnom Penh',
#  'สมุทรสาคร',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'กรุงเทพ',
#  'น่าน',
#  'น่าน',
#  'ลำพูน',
#  'น่าน',
#  'ลำพูน',
#  'กรุงเทพ',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'เชียงใหม่',
#  'กรุงเทพ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'น่าน',
#  'Phnom Penh',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ระยอง',
#  'กรุงเทพ',
#  'กรุงเทพ',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
import csv

list1 = sen
list2 = Name
list3 = Lat
list4 = Lon
list5 = Prov

# Combine the lists into a single list of tuples
combined_lists = list(zip(list1, list2, list3,list4,list5))

# Define the filename for the CSV file
filename = 'Sensor.csv'

# Write the data to the CSV file
with open(filename, 'w',encoding='utf-8-sig', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Sensor', 'Name', 'Lat','Lon','Prov'])  # Write the header
    writer.writerows(combined_lists)  # Write the data rows

print(f"The data has been written to {filename}.")
# Out:
# The data has been written to Sensor.csv.

# %% [markdown]
# # **ข้อมูลค่ามลพิษ**

# %% [markdown]
# **Get lastest 1 hour averaged data of all active stations.**

# %%
url2 = 'https://www.cusense.net:8082/api/v1/sensorData/realtime/all'
headers = {
    'Content-Type': 'application/json',
    'X-Gravitee-Api-Key': '7be9f42f-7e74-4822-972d-5c1e3e783c9d'
}
response = requests.get(url2, headers=headers)
if response.status_code == 200:
    # Successful request
    realtime = response.json()
    print(realtime)
# Out:
# {'cusensor2/0424D01F9C9C': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 0, 'pm25': 0, 'pm10': 1, 'temp': 29.4, 'co2': 697.3, 'humid': 55, 'topic': 'cusensor2/0424D01F9C9C'}], 'info': {'topic': 'cusensor2/0424D01F9C9C', 'project': 'cusensor2', 'id': '0424D01F9C9C', 'lat': '13.738300', 'lon': '100.528816', 'name': 'จามจุรี 5 ชั้น 3', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/0C44F5C40A24': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 4, 'pm25': 2, 'pm10': 7, 'temp': 33.4, 'co2': 575.175, 'humid': 47, 'topic': 'cusensor2/0C44F5C40A24'}], 'info': {'topic': 'cusensor2/0C44F5C40A24', 'project': 'cusensor2', 'id': '0C44F5C40A24', 'lat': '13.742675', 'lon': '100.528077', 'name': 'จามจุรี 10 ชั้น 11', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/40F5203F0828': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 5, 'pm25': 3, 'pm10': 8, 'temp': 26.9, 'co2': None, 'humid': 78, 'topic': 'cusensor2/40F5203F0828'}], 'info': {'topic': 'cusensor2/40F5203F0828', 'project': 'cusensor2', 'id': '40F5203F0828', 'lat': '13.742930', 'lon': '100.532150', 'name': 'ห้องปฏิบัติการเคมี สถาบันวิจัยสภาวะแวดล้อม (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/40F5203F7FBF': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 5, 'pm25': 2, 'pm10': 6, 'temp': 29.1, 'co2': None, 'humid': 43, 'topic': 'cusensor2/40F5203F7FBF'}], 'info': {'topic': 'cusensor2/40F5203F7FBF', 'project': 'cusensor2', 'id': '40F5203F7FBF', 'lat': '13.736020', 'lon': '100.530590', 'name': 'ภาควิชาเคมีเทคนิค ชั้น ห้อง 1810 อาคารมหามกุฎ (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/40F5203F88E0': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 5, 'pm25': 2, 'pm10': 7, 'temp': 26.2, 'co2': None, 'humid': 62, 'topic': 'cusensor2/40F5203F88E0'}], 'info': {'topic': 'cusensor2/40F5203F88E0', 'project': 'cusensor2', 'id': '40F5203F88E0', 'lat': '13.742830', 'lon': '100.528250', 'name': 'EDS Program (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/60019440B7A6': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 0, 'pm25': 0, 'pm10': 0, 'temp': 28.4, 'co2': 563.4285714285714, 'humid': 51, 'topic': 'cusensor2/60019440B7A6'}], 'info': {'topic': 'cusensor2/60019440B7A6', 'project': 'cusensor2', 'id': '60019440B7A6', 'lat': '13.732152', 'lon': '100.537307', 'name': 'อาคารภูมิสิริ ชั้น 1 (หน้า ER) (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/60019440B7B7': {'data': [{'time': '2023-08-18T12:00:00.000Z', 'pm1': 0, 'pm25': 0, 'pm10': 0, 'temp': 32.1, 'co2': 0, 'humid': 74, 'topic': 'cusensor2/60019440B7B7'}], 'info': {'topic': 'cusensor2/60019440B7B7', 'project': 'cusensor2', 'id': '60019440B7B7', 'lat': '13.732318', 'lon': '100.537199', 'name': 'อาคารภูมิสิริ ชั้น 14 (Indoor)', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/60019440B808': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 1, 'pm25': 2, 'pm10': 2, 'temp': 32.3, 'co2': 65430, 'humid': 55, 'topic': 'cusensor2/60019440B808'}], 'info': {'topic': 'cusensor2/60019440B808', 'project': 'cusensor2', 'id': '60019440B808', 'lat': '13.735188', 'lon': '100.532189', 'name': 'สถาบันภาษา', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/60019440B80B': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 4, 'pm25': 7, 'pm10': 8, 'temp': 33.1, 'co2': 406.125, 'humid': 94, 'topic': 'cusensor2/60019440B80B'}], 'info': {'topic': 'cusensor2/60019440B80B', 'project': 'cusensor2', 'id': '60019440B80B', 'lat': '13.737531', 'lon': '100.526655', 'name': 'สาธิตจุฬาประถม ประตู 5', 'tambol': 'วังใหม่', 'amphoe': 'ปทุมวัน', 'province': 'กรุงเทพ'}}, 'cusensor2/60019440B8BA': {'data': [{'time': '2023-08-18T14:00:00.000Z', 'pm1': 0, 'pm25': 0, 'pm10': 0, 'temp': 27.8, 'co2': 65535, 'humid': 51, 'topic': 'cusensor2/60019440B8BA'}], 'info': {' ...

# %%
realtime
# Out:
# {'cusensor2/0424D01F9C9C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 1,
#     'temp': 29.4,
#     'co2': 697.3,
#     'humid': 55,
#     'topic': 'cusensor2/0424D01F9C9C'}],
#   'info': {'topic': 'cusensor2/0424D01F9C9C',
#    'project': 'cusensor2',
#    'id': '0424D01F9C9C',
#    'lat': '13.738300',
#    'lon': '100.528816',
#    'name': 'จามจุรี 5 ชั้น 3',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/0C44F5C40A24': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 2,
#     'pm10': 7,
#     'temp': 33.4,
#     'co2': 575.175,
#     'humid': 47,
#     'topic': 'cusensor2/0C44F5C40A24'}],
#   'info': {'topic': 'cusensor2/0C44F5C40A24',
#    'project': 'cusensor2',
#    'id': '0C44F5C40A24',
#    'lat': '13.742675',
#    'lon': '100.528077',
#    'name': 'จามจุรี 10 ชั้น 11',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/40F5203F0828': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 3,
#     'pm10': 8,
#     'temp': 26.9,
#     'co2': None,
#     'humid': 78,
#     'topic': 'cusensor2/40F5203F0828'}],
#   'info': {'topic': 'cusensor2/40F5203F0828',
#    'project': 'cusensor2',
#    'id': '40F5203F0828',
#    'lat': '13.742930',
#    'lon': '100.532150',
#    'name': 'ห้องปฏิบัติการเคมี สถาบันวิจัยสภาวะแวดล้อม (Indoor)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/40F5203F7FBF': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 2,
#     'pm10': 6,
#     'temp': 29.1,
#     'co2': None,
#     'humid': 43,
#     'topic': 'cusensor2/40F5203F7FBF'}],
#   'info': {'topic': 'cusensor2/40F5203F7FBF',
#    'project': 'cusensor2',
#    'id': '40F5203F7FBF',
#    'lat': '13.736020',
#    'lon': '100.530590',
#    'name': 'ภาควิชาเคมีเทคนิค ชั้น ห้อง 1810 อาคารมหามกุฎ (Indoor)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/40F5203F88E0': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 2,
#     'pm10': 7,
#     'temp': 26.2,
#     'co2': None,
#     'humid': 62,
#     'topic': 'cusensor2/40F5203F88E0'}],
#   'info': {'topic': 'cusensor2/40F5203F88E0',
#    'project': 'cusensor2',
#    'id': '40F5203F88E0',
#    'lat': '13.742830',
#    'lon': '100.528250',
#    'name': 'EDS Program (Indoor)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/60019440B7A6': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 28.4,
#     'co2': 563.4285714285714,
#     'humid': 51,
#     'topic': 'cusensor2/60019440B7A6'}],
#   'info': {'topic': 'cusensor2/60019440B7A6',
#    'project': 'cusensor2',
#    'id': '60019440B7A6',
#    'lat': '13.732152',
#    'lon': '100.537307',
#    'name': 'อาคารภูมิสิริ ชั้น 1 (หน้า ER) (Indoor)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/60019440B7B7': {'data': [{'time': '2023-08-18T12:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 32.1,
#     'co2': 0,
#     'humid': 74,
#     'topic': 'cusensor2/60019440B7B7'}],
#   'info': {'topic': 'cusensor2/60019440B7B7',
#    'project': 'cusensor2',
#    'id': '60019440B7B7',
#    'lat': '13.732318',
#    'lon': '100.537199',
#    'name': 'อาคารภูมิสิริ ชั้น 14 (Indoor)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/60019440B808': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 1,
#     'pm25': 2,
#     'pm10': 2,
#     'temp': 32.3,
#     'co2': 65430,
#     'humid': 55,
#     'topic': 'cusensor2/60019440B808'}],
#   'info': {'topic': 'cusensor2/60019440B808',
#    'project': 'cusensor2',
#    'id': '60019440B808',
#    'lat': '13.735188',
#    'lon': '100.532189',
#    'name': 'สถาบันภาษา',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/60019440B80B': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 7,
#     'pm10': 8,
#     'temp': 33.1,
#     'co2': 406.125,
#     'humid': 94,
#     'topic': 'cusensor2/60019440B80B'}],
#   'info': {'topic': 'cusensor2/60019440B80B',
#    'project': 'cusensor2',
#    'id': '60019440B80B',
#    'lat': '13.737531',
#    'lon': '100.526655',
#    'name': 'สาธิตจุฬาประถม ประตู 5',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/60019440B8BA': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 27.8,
#     'co2': 65535,
#     'humid': 51,
#     'topic': 'cusensor2/60019440B8BA'}],
#   'info': {'topic': 'cusensor2/60019440B8BA',
#    'project': 'cusensor2',
#    'id': '60019440B8BA',
#    'lat': '13.738978',
#    'lon': '100.527644',
#    'name': 'หอสมุดกลาง (Indoor)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/68C63A8E5B80': {'data': [{'time': '2023-08-18T13:00:00.000Z',
#     'pm1': 3,
#     'pm25': 5,
#     'pm10': 6,
#     'temp': 33.6,
#     'co2': 0,
#     'humid': 83,
#     'topic': 'cusensor2/68C63A8E5B80'}],
#   'info': {'topic': 'cusensor2/68C63A8E5B80',
#    'project': 'cusensor2',
#    'id': '68C63A8E5B80',
#    'lat': '13.738693',
#    'lon': '100.525834',
#    'name': 'โรงยิมจุฬาฯ\r\n',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/68C63A8E5BB6': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 1,
#     'pm25': 2,
#     'pm10': 2,
#     'temp': 31.7,
#     'co2': 0,
#     'humid': 94,
#     'topic': 'cusensor2/68C63A8E5BB6'}],
#   'info': {'topic': 'cusensor2/68C63A8E5BB6',
#    'project': 'cusensor2',
#    'id': '68C63A8E5BB6',
#    'lat': '13.743853',
#    'lon': '100.525705',
#    'name': 'จุฬาพัฒน์ 14',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/869405031319016': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 11,
#     'pm10': 17,
#     'temp': 31.5,
#     'co2': None,
#     'humid': 75,
#     'topic': 'cusensor2/869405031319016'}],
#   'info': {'topic': 'cusensor2/869405031319016',
#    'project': 'cusensor2',
#    'id': '869405031319016',
#    'lat': '13.739916',
#    'lon': '100.523114',
#    'name': 'สวน 100 ปี (พื้นที่สูง)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/869405031319123': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 11,
#     'pm10': 16,
#     'temp': 31.5,
#     'co2': None,
#     'humid': 77,
#     'topic': 'cusensor2/869405031319123'}],
#   'info': {'topic': 'cusensor2/869405031319123',
#    'project': 'cusensor2',
#    'id': '869405031319123',
#    'lat': '13.738976',
#    'lon': '100.524824',
#    'name': 'สวน 100 ปี (ข้างสระน้ำ)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/B01ED01F9C9C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 3,
#     'pm25': 2,
#     'pm10': 5,
#     'temp': 29.6,
#     'co2': 442.875,
#     'humid': 42,
#     'topic': 'cusensor2/B01ED01F9C9C'}],
#   'info': {'topic': 'cusensor2/B01ED01F9C9C',
#    'project': 'cusensor2',
#    'id': 'B01ED01F9C9C',
#    'lat': '13.735858',
#    'lon': '100.526072',
#    'name': 'จามจุรี 9 ชั้น 3',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor2/D478F5C40A24': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 2,
#     'pm10': 6,
#     'temp': 30.6,
#     'co2': 599.5,
#     'humid': 50,
#     'topic': 'cusensor2/D478F5C40A24'}],
#   'info': {'topic': 'cusensor2/D478F5C40A24',
#    'project': 'cusensor2',
#    'id': 'D478F5C40A24',
#    'lat': '13.735921',
#    'lon': '100.530489',
#    'name': 'มหามกุฏ คณะวิทยาศาสตร์',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/240AC4588CF8': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 75,
#     'pm25': 80,
#     'pm10': 92,
#     'temp': 30.7,
#     'co2': None,
#     'humid': 82,
#     'topic': 'cusensor3/240AC4588CF8'}],
#   'info': {'topic': 'cusensor3/240AC4588CF8',
#    'project': 'cusensor3',
#    'id': '240AC4588CF8',
#    'lat': '18.560438',
#    'lon': '100.752007',
#    'name': 'โรงเรียนสา (1)',
#    'tambol': 'ไหล่น่าน',
#    'amphoe': 'เวียงสา',
#    'province': 'น่าน'}},
#  'cusensor3/240AC4589680': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 2,
#     'pm25': 5,
#     'pm10': 2,
#     'temp': 31.2,
#     'co2': None,
#     'humid': 74,
#     'topic': 'cusensor3/240AC4589680'}],
#   'info': {'topic': 'cusensor3/240AC4589680',
#    'project': 'cusensor3',
#    'id': '240AC4589680',
#    'lat': '19.089639',
#    'lon': '100.896645',
#    'name': 'อบต.ยม',
#    'tambol': 'ยม',
#    'amphoe': 'ท่าวังผา',
#    'province': 'น่าน'}},
#  'cusensor3/240AC458FE8C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 6,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 32.7,
#     'co2': None,
#     'humid': 71,
#     'topic': 'cusensor3/240AC458FE8C'}],
#   'info': {'topic': 'cusensor3/240AC458FE8C',
#    'project': 'cusensor3',
#    'id': '240AC458FE8C',
#    'lat': '18.707911',
#    'lon': '100.676518',
#    'name': 'อบต.นาซาว',
#    'tambol': 'นาซาว',
#    'amphoe': 'เมืองน่าน',
#    'province': 'น่าน'}},
#  'cusensor3/240AC4592908': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 3,
#     'pm25': 5,
#     'pm10': 6,
#     'temp': 29.4,
#     'co2': None,
#     'humid': 74,
#     'topic': 'cusensor3/240AC4592908'}],
#   'info': {'topic': 'cusensor3/240AC4592908',
#    'project': 'cusensor3',
#    'id': '240AC4592908',
#    'lat': '19.115223',
#    'lon': '100.946672',
#    'name': 'อบต.ศิลาเพชร',
#    'tambol': 'ศิลาเพชร',
#    'amphoe': 'ปัว',
#    'province': 'น่าน'}},
#  'cusensor3/240AC4C656F8': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 36.4,
#     'co2': None,
#     'humid': 54,
#     'topic': 'cusensor3/240AC4C656F8'}],
#   'info': {'topic': 'cusensor3/240AC4C656F8',
#    'project': 'cusensor3',
#    'id': '240AC4C656F8',
#    'lat': '13.740698',
#    'lon': '100.527156',
#    'name': 'วิทยนิเวศน์',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/240AC4C66068': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 1,
#     'pm25': 3,
#     'pm10': 4,
#     'temp': 35.6,
#     'co2': None,
#     'humid': 59,
#     'topic': 'cusensor3/240AC4C66068'}],
#   'info': {'topic': 'cusensor3/240AC4C66068',
#    'project': 'cusensor3',
#    'id': '240AC4C66068',
#    'lat': '13.739178',
#    'lon': '100.528683',
#    'name': 'โรงอาหารรวม',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289D7CE8': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 2,
#     'pm25': 4,
#     'pm10': 5,
#     'temp': 34.3,
#     'co2': None,
#     'humid': 63,
#     'topic': 'cusensor3/246F289D7CE8'}],
#   'info': {'topic': 'cusensor3/246F289D7CE8',
#    'project': 'cusensor3',
#    'id': '246F289D7CE8',
#    'lat': '13.742253',
#    'lon': '100.534268',
#    'name': 'โรงพยาบาลสัตว์เล็ก(อาคารสัตววิทยวิจักษ์)',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289D7F1C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 2,
#     'pm25': 4,
#     'pm10': 5,
#     'temp': 34.7,
#     'co2': None,
#     'humid': 61,
#     'topic': 'cusensor3/246F289D7F1C'}],
#   'info': {'topic': 'cusensor3/246F289D7F1C',
#    'project': 'cusensor3',
#    'id': '246F289D7F1C',
#    'lat': '13.742292',
#    'lon': '100.533517',
#    'name': 'อาคาร 60 ปี',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289E11D4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 7,
#     'pm25': 12,
#     'pm10': 15,
#     'temp': 34.7,
#     'co2': None,
#     'humid': 61,
#     'topic': 'cusensor3/246F289E11D4'}],
#   'info': {'topic': 'cusensor3/246F289E11D4',
#    'project': 'cusensor3',
#    'id': '246F289E11D4',
#    'lat': '13.736372',
#    'lon': '100.533868',
#    'name': 'อาคารวิศว 100 ปี',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289E1BE4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 2,
#     'pm25': 4,
#     'pm10': 6,
#     'temp': 34.3,
#     'co2': None,
#     'humid': 61,
#     'topic': 'cusensor3/246F289E1BE4'}],
#   'info': {'topic': 'cusensor3/246F289E1BE4',
#    'project': 'cusensor3',
#    'id': '246F289E1BE4',
#    'lat': '13.743233',
#    'lon': '100.528251',
#    'name': 'คณะสหเวชศาสตร์',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289E906C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 36,
#     'pm25': 40,
#     'pm10': 43,
#     'temp': 35,
#     'co2': None,
#     'humid': 61,
#     'topic': 'cusensor3/246F289E906C'}],
#   'info': {'topic': 'cusensor3/246F289E906C',
#    'project': 'cusensor3',
#    'id': '246F289E906C',
#    'lat': '13.743517',
#    'lon': '100.527009',
#    'name': 'คณะวิทยาศาสตร์การกีฬา',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289EA1B4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 2,
#     'pm25': 5,
#     'pm10': 5,
#     'temp': 33.5,
#     'co2': None,
#     'humid': 63,
#     'topic': 'cusensor3/246F289EA1B4'}],
#   'info': {'topic': 'cusensor3/246F289EA1B4',
#    'project': 'cusensor3',
#    'id': '246F289EA1B4',
#    'lat': '13.739848',
#    'lon': '100.530826',
#    'name': 'คณะสถาปัตยกรรมศาสตร์',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289EA56C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 8,
#     'pm10': 9,
#     'temp': 34.8,
#     'co2': None,
#     'humid': 60,
#     'topic': 'cusensor3/246F289EA56C'}],
#   'info': {'topic': 'cusensor3/246F289EA56C',
#    'project': 'cusensor3',
#    'id': '246F289EA56C',
#    'lat': '13.734199',
#    'lon': '100.532462',
#    'name': 'อาคารวิศิษฐ์ ประจวบเหมาะ',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F289EA798': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 2,
#     'pm25': 5,
#     'pm10': 6,
#     'temp': 34.2,
#     'co2': None,
#     'humid': 63,
#     'topic': 'cusensor3/246F289EA798'}],
#   'info': {'topic': 'cusensor3/246F289EA798',
#    'project': 'cusensor3',
#    'id': '246F289EA798',
#    'lat': '13.736886',
#    'lon': '100.533849',
#    'name': 'ห้องพัสดุ วิศวกรรมศาสตร์',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F28B45C80': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 6,
#     'pm10': 8,
#     'temp': 33.2,
#     'co2': None,
#     'humid': 65,
#     'topic': 'cusensor3/246F28B45C80'}],
#   'info': {'topic': 'cusensor3/246F28B45C80',
#    'project': 'cusensor3',
#    'id': '246F28B45C80',
#    'lat': '13.736979',
#    'lon': '100.532921',
#    'name': 'Live&Learn คณะวิศวกรรมศาสตร์',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/246F28B4FFB8': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 7,
#     'pm10': 8,
#     'temp': 35.3,
#     'co2': None,
#     'humid': 60,
#     'topic': 'cusensor3/246F28B4FFB8'}],
#   'info': {'topic': 'cusensor3/246F28B4FFB8',
#    'project': 'cusensor3',
#    'id': '246F28B4FFB8',
#    'lat': '13.735482',
#    'lon': '100.532449',
#    'name': 'ภาควิชาวิศวกรรมสำรวจ',
#    'tambol': 'วังใหม่',
#    'amphoe': 'ปทุมวัน',
#    'province': 'กรุงเทพ'}},
#  'cusensor3/7C9EBDF4DCE4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 7,
#     'pm25': 11,
#     'pm10': 11,
#     'temp': 31.7,
#     'co2': None,
#     'humid': 74,
#     'topic': 'cusensor3/7C9EBDF4DCE4'}],
#   'info': {'topic': 'cusensor3/7C9EBDF4DCE4',
#    'project': 'cusensor3',
#    'id': '7C9EBDF4DCE4',
#    'lat': '18.864058',
#    'lon': '100.829019',
#    'name': 'อบต.เมืองจัง',
#    'tambol': 'เมืองจัง',
#    'amphoe': 'ภูเพียง',
#    'province': 'น่าน'}},
#  'cusensor3/7C9EBDF4DE94': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 6,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 29.9,
#     'co2': None,
#     'humid': 75,
#     'topic': 'cusensor3/7C9EBDF4DE94'}],
#   'info': {'topic': 'cusensor3/7C9EBDF4DE94',
#    'project': 'cusensor3',
#    'id': '7C9EBDF4DE94',
#    'lat': '18.303170',
#    'lon': '100.595541',
#    'name': 'อบต.สันทะ',
#    'tambol': 'สันทะ',
#    'amphoe': 'นาน้อย',
#    'province': 'น่าน'}},
#  'cusensor3/7C9EBDF4E32C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 9,
#     'pm25': 15,
#     'pm10': 17,
#     'temp': 30.8,
#     'co2': None,
#     'humid': 77,
#     'topic': 'cusensor3/7C9EBDF4E32C'}],
#   'info': {'topic': 'cusensor3/7C9EBDF4E32C',
#    'project': 'cusensor3',
#    'id': '7C9EBDF4E32C',
#    'lat': '19.388265',
#    'lon': '100.877907',
#    'name': 'ทต.ทุ่งช้าง',
#    'tambol': 'ทุ่งช้าง',
#    'amphoe': 'ทุ่งช้าง',
#    'province': 'น่าน'}},
#  'cusensor3/7C9EBDF4E430': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 12,
#     'pm25': 18,
#     'pm10': 20,
#     'temp': 32.6,
#     'co2': None,
#     'humid': 71,
#     'topic': 'cusensor3/7C9EBDF4E430'}],
#   'info': {'topic': 'cusensor3/7C9EBDF4E430',
#    'project': 'cusensor3',
#    'id': '7C9EBDF4E430',
#    'lat': '18.701362',
#    'lon': '100.807486',
#    'name': 'อบต.นาปัง',
#    'tambol': 'นาปัง',
#    'amphoe': 'ภูเพียง',
#    'province': 'น่าน'}},
#  'cusensor3/7C9EBDF4E780': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 7,
#     'pm10': 8,
#     'temp': 29.1,
#     'co2': None,
#     'humid': 77,
#     'topic': 'cusensor3/7C9EBDF4E780'}],
#   'info': {'topic': 'cusensor3/7C9EBDF4E780',
#    'project': 'cusensor3',
#    'id': '7C9EBDF4E780',
#    'lat': '19.024651',
#    'lon': '101.204885',
#    'name': 'ศูนย์ภูฟ้าพัฒนาอันเนื่องมาจากพระราชดำริฯ',
#    'tambol': 'ภูฟ้า',
#    'amphoe': 'บ่อเกลือ',
#    'province': 'น่าน'}},
#  'cusensor3/7C9EBDF4E7C4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 25,
#     'pm25': 40,
#     'pm10': 45,
#     'temp': 31.6,
#     'co2': None,
#     'humid': 80,
#     'topic': 'cusensor3/7C9EBDF4E7C4'}],
#   'info': {'topic': 'cusensor3/7C9EBDF4E7C4',
#    'project': 'cusensor3',
#    'id': '7C9EBDF4E7C4',
#    'lat': '18.680986',
#    'lon': '100.755750',
#    'name': 'ทต.กองควาย',
#    'tambol': 'กองควาย',
#    'amphoe': 'เมืองน่าน',
#    'province': 'น่าน'}},
#  'cusensor3/7C9EBDF4EAA4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 7,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 29.9,
#     'co2': None,
#     'humid': 82,
#     'topic': 'cusensor3/7C9EBDF4EAA4'}],
#   'info': {'topic': 'cusensor3/7C9EBDF4EAA4',
#    'project': 'cusensor3',
#    'id': '7C9EBDF4EAA4',
#    'lat': '18.810646',
#    'lon': '100.708530',
#    'name': 'อบต.สะเนียน',
#    'tambol': 'เมืองจัง',
#    'amphoe': 'ภูเพียง',
#    'province': 'น่าน'}},
#  'cusensor3/7C9EBDF50438': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 21,
#     'pm25': 32,
#     'pm10': 36,
#     'temp': 31.3,
#     'co2': None,
#     'humid': 79,
#     'topic': 'cusensor3/7C9EBDF50438'}],
#   'info': {'topic': 'cusensor3/7C9EBDF50438',
#    'project': 'cusensor3',
#    'id': '7C9EBDF50438',
#    'lat': '19.170129',
#    'lon': '100.835931',
#    'name': 'โรงเรียนบ้านปงสนุก',
#    'tambol': 'เจดีย์ชัย',
#    'amphoe': 'ปัว',
#    'province': 'น่าน'}},
#  'cusensor3/8CAAB584DBF0': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 22,
#     'pm25': 33,
#     'pm10': 38,
#     'temp': 31.8,
#     'co2': None,
#     'humid': 79,
#     'topic': 'cusensor3/8CAAB584DBF0'}],
#   'info': {'topic': 'cusensor3/8CAAB584DBF0',
#    'project': 'cusensor3',
#    'id': '8CAAB584DBF0',
#    'lat': '19.168987',
#    'lon': '100.829243',
#    'name': 'รพ.สต.เจดีย์ชัย',
#    'tambol': 'เจดีย์ชัย',
#    'amphoe': 'ปัว',
#    'province': 'น่าน'}},
#  'cusensor3/8CAAB5851AD4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 29.6,
#     'co2': None,
#     'humid': 59,
#     'topic': 'cusensor3/8CAAB5851AD4'}],
#   'info': {'topic': 'cusensor3/8CAAB5851AD4',
#    'project': 'cusensor3',
#    'id': '8CAAB5851AD4',
#    'lat': '17.669825',
#    'lon': '98.869539',
#    'name': 'อุทยานแห่งชาติแม่ปิง',
#    'tambol': 'ก้อ',
#    'amphoe': 'ลี้',
#    'province': 'ลำพูน'}},
#  'cusensor3/8CAAB58527DC': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 8,
#     'pm25': 13,
#     'pm10': 14,
#     'temp': 31.7,
#     'co2': None,
#     'humid': 72,
#     'topic': 'cusensor3/8CAAB58527DC'}],
#   'info': {'topic': 'cusensor3/8CAAB58527DC',
#    'project': 'cusensor3',
#    'id': '8CAAB58527DC',
#    'lat': '19.179893',
#    'lon': '100.908915',
#    'name': 'ทต.ปัว',
#    'tambol': 'ปัว',
#    'amphoe': 'ปัว',
#    'province': 'น่าน'}},
#  'cusensor3/8CAAB5852984': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 33.2,
#     'co2': None,
#     'humid': 48,
#     'topic': 'cusensor3/8CAAB5852984'}],
#   'info': {'topic': 'cusensor3/8CAAB5852984',
#    'project': 'cusensor3',
#    'id': '8CAAB5852984',
#    'lat': '17.639110',
#    'lon': '98.785331',
#    'name': 'ทต.ก้อ',
#    'tambol': 'ก้อ',
#    'amphoe': 'ลี้',
#    'province': 'ลำพูน'}},
#  'cusensor3/B8F009CD03A8': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 22,
#     'pm25': 36,
#     'pm10': 7,
#     'temp': 30,
#     'co2': None,
#     'humid': 80,
#     'topic': 'cusensor3/B8F009CD03A8'}],
#   'info': {'topic': 'cusensor3/B8F009CD03A8',
#    'project': 'cusensor3',
#    'id': 'B8F009CD03A8',
#    'lat': '19.136272',
#    'lon': '100.792183',
#    'name': 'อบต.ผาตอ',
#    'tambol': 'ผาตอ',
#    'amphoe': 'ท่าวังผา',
#    'province': 'น่าน'}},
#  'cusensor3/B8F009CD07DC': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 25,
#     'pm25': 42,
#     'pm10': 48,
#     'temp': 30.8,
#     'co2': None,
#     'humid': 78,
#     'topic': 'cusensor3/B8F009CD07DC'}],
#   'info': {'topic': 'cusensor3/B8F009CD07DC',
#    'project': 'cusensor3',
#    'id': 'B8F009CD07DC',
#    'lat': '19.168417',
#    'lon': '100.828003',
#    'name': 'โรงเรียนบ้านนาวงศ์',
#    'tambol': 'เจดีย์ชัย',
#    'amphoe': 'ปัว',
#    'province': 'น่าน'}},
#  'cusensor3/B8F009CD113C': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 22,
#     'pm25': 33,
#     'pm10': 38,
#     'temp': 32.3,
#     'co2': None,
#     'humid': 79,
#     'topic': 'cusensor3/B8F009CD113C'}],
#   'info': {'topic': 'cusensor3/B8F009CD113C',
#    'project': 'cusensor3',
#    'id': 'B8F009CD113C',
#    'lat': '18.573951',
#    'lon': '100.760508',
#    'name': 'โรงเรียนบ้านไหล่น่าน',
#    'tambol': 'ไหล่น่าน',
#    'amphoe': 'เวียงสา',
#    'province': 'น่าน'}},
#  'cusensor3/B8F009CD1878': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 6,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 30.9,
#     'co2': None,
#     'humid': 76,
#     'topic': 'cusensor3/B8F009CD1878'}],
#   'info': {'topic': 'cusensor3/B8F009CD1878',
#    'project': 'cusensor3',
#    'id': 'B8F009CD1878',
#    'lat': '19.422232',
#    'lon': '100.879537',
#    'name': 'อบต.และ',
#    'tambol': 'และ',
#    'amphoe': 'ทุ่งช้าง',
#    'province': 'น่าน'}},
#  'cusensor3/B8F009CD18F4': {'data': [{'time': '2023-08-18T12:00:00.000Z',
#     'pm1': 14,
#     'pm25': 23,
#     'pm10': 25,
#     'temp': 32.7,
#     'co2': None,
#     'humid': 79,
#     'topic': 'cusensor3/B8F009CD18F4'}],
#   'info': {'topic': 'cusensor3/B8F009CD18F4',
#    'project': 'cusensor3',
#    'id': 'B8F009CD18F4',
#    'lat': '19.094328',
#    'lon': '100.843998',
#    'name': 'รร.บ้านยู้',
#    'tambol': 'จอมพระ',
#    'amphoe': 'ท่าวังผา',
#    'province': 'น่าน'}},
#  'cusensor3/B8F009CD1DB4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 19,
#     'pm25': 30,
#     'pm10': 34,
#     'temp': 32.6,
#     'co2': None,
#     'humid': 72,
#     'topic': 'cusensor3/B8F009CD1DB4'}],
#   'info': {'topic': 'cusensor3/B8F009CD1DB4',
#    'project': 'cusensor3',
#    'id': 'B8F009CD1DB4',
#    'lat': '18.565796',
#    'lon': '100.735844',
#    'name': 'ทต.กลางเวียง',
#    'tambol': 'กลางเวียง',
#    'amphoe': 'เวียงสา',
#    'province': 'น่าน'}},
#  'cusensor3/B8F009CD1F20': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 2,
#     'pm25': 4,
#     'pm10': 5,
#     'temp': 31.1,
#     'co2': None,
#     'humid': 72,
#     'topic': 'cusensor3/B8F009CD1F20'}],
#   'info': {'topic': 'cusensor3/B8F009CD1F20',
#    'project': 'cusensor3',
#    'id': 'B8F009CD1F20',
#    'lat': '18.775246',
#    'lon': '100.687514',
#    'name': 'อบต.เรือง',
#    'tambol': 'เรือง',
#    'amphoe': 'เมืองน่าน',
#    'province': 'น่าน'}},
#  'Dustboy/110': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 6,
#     'pm10': 8,
#     'temp': 35,
#     'co2': None,
#     'humid': 100,
#     'topic': 'Dustboy/110'}],
#   'info': {'topic': 'Dustboy/110',
#    'project': 'Dustboy',
#    'id': '110',
#    'lat': '13.800444',
#    'lon': '100.591697',
#    'name': 'มูลนิธิเพื่อเด็กพิการ กรุงเทพฯ',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/13': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 12,
#     'pm10': 13,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/13'}],
#   'info': {'topic': 'Dustboy/13',
#    'project': 'Dustboy',
#    'id': '13',
#    'lat': '19.137406',
#    'lon': '98.959848',
#    'name': 'รพ. แม่แตง จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/18': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 16,
#     'pm10': 27,
#     'temp': 29,
#     'co2': None,
#     'humid': 99,
#     'topic': 'Dustboy/18'}],
#   'info': {'topic': 'Dustboy/18',
#    'project': 'Dustboy',
#    'id': '18',
#    'lat': '18.744605',
#    'lon': '99.221795',
#    'name': 'รพ. แม่ออน จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/24': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 22,
#     'pm10': 24,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/24'}],
#   'info': {'topic': 'Dustboy/24',
#    'project': 'Dustboy',
#    'id': '24',
#    'lat': '18.683101',
#    'lon': '98.918202',
#    'name': 'รพ. หางดง จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/25': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 32,
#     'co2': None,
#     'humid': 62,
#     'topic': 'Dustboy/25'}],
#   'info': {'topic': 'Dustboy/25',
#    'project': 'Dustboy',
#    'id': '25',
#    'lat': '18.846650',
#    'lon': '98.732204',
#    'name': 'รพ. สะเมิง จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/26': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 16,
#     'pm10': 18,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/26'}],
#   'info': {'topic': 'Dustboy/26',
#    'project': 'Dustboy',
#    'id': '26',
#    'lat': '18.615982',
#    'lon': '98.774379',
#    'name': 'รพ. แม่วาง จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/30': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 1,
#     'pm10': 1,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/30'}],
#   'info': {'topic': 'Dustboy/30',
#    'project': 'Dustboy',
#    'id': '30',
#    'lat': '17.801972',
#    'lon': '98.359021',
#    'name': 'รพ. อมก๋อย จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/3002': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 14,
#     'pm10': 16,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/3002'}],
#   'info': {'topic': 'Dustboy/3002',
#    'project': 'Dustboy',
#    'id': '3002',
#    'lat': '12.674423',
#    'lon': '101.221530',
#    'name': 'รพ. กรุงเทพระยอง จุดที่ 2 จ. ระยอง',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/31': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 8,
#     'pm10': 8,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/31'}],
#   'info': {'topic': 'Dustboy/31',
#    'project': 'Dustboy',
#    'id': '31',
#    'lat': '18.498206',
#    'lon': '98.379513',
#    'name': 'รพ. เทพรัตนเวชชานุกูล จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/33': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 32,
#     'pm10': 37,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/33'}],
#   'info': {'topic': 'Dustboy/33',
#    'project': 'Dustboy',
#    'id': '33',
#    'lat': '19.366273',
#    'lon': '98.964704',
#    'name': 'สสอ. เชียงดาว จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/34': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 5,
#     'pm10': 18,
#     'temp': 32,
#     'co2': None,
#     'humid': 75,
#     'topic': 'Dustboy/34'}],
#   'info': {'topic': 'Dustboy/34',
#    'project': 'Dustboy',
#    'id': '34',
#    'lat': '19.559988',
#    'lon': '98.635244',
#    'name': 'รพ. เวียงแหง จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/37': {'data': [{'time': '2023-08-18T12:00:00.000Z',
#     'pm1': None,
#     'pm25': 4,
#     'pm10': 5,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/37'}],
#   'info': {'topic': 'Dustboy/37',
#    'project': 'Dustboy',
#    'id': '37',
#    'lat': '18.772478',
#    'lon': '98.995551',
#    'name': 'รพ. ส่งเสริมสุขภาพ เขต 1 จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/38': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 14,
#     'pm10': 15,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/38'}],
#   'info': {'topic': 'Dustboy/38',
#    'project': 'Dustboy',
#    'id': '38',
#    'lat': '18.851765',
#    'lon': '98.967230',
#    'name': 'รพ. นครพิงค์ จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 21,
#     'pm10': 22,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/4'}],
#   'info': {'topic': 'Dustboy/4',
#    'project': 'Dustboy',
#    'id': '4',
#    'lat': '18.785477',
#    'lon': '98.999660',
#    'name': 'ไนท์บาร์ซาร์ จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4010': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 4,
#     'pm10': 5,
#     'temp': 28,
#     'co2': None,
#     'humid': 68,
#     'topic': 'Dustboy/4010'}],
#   'info': {'topic': 'Dustboy/4010',
#    'project': 'Dustboy',
#    'id': '4010',
#    'lat': '18.867019',
#    'lon': '98.964180',
#    'name': 'ทางลอดอุโมงค์ดอนแก้วทางหลวงหมายเลข107 (ถนนโชตนา) จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4032': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 12,
#     'pm10': 14,
#     'temp': 29,
#     'co2': None,
#     'humid': 69,
#     'topic': 'Dustboy/4032'}],
#   'info': {'topic': 'Dustboy/4032',
#    'project': 'Dustboy',
#    'id': '4032',
#    'lat': '20.134888',
#    'lon': '99.859792',
#    'name': 'โรงพยาบาลแม่จัน จ. เชียงราย',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4039': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 31,
#     'co2': None,
#     'humid': 58,
#     'topic': 'Dustboy/4039'}],
#   'info': {'topic': 'Dustboy/4039',
#    'project': 'Dustboy',
#    'id': '4039',
#    'lat': '19.690450',
#    'lon': '100.176290',
#    'name': 'โรงพยาบาลเทิง จ. เชียงราย',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4042': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 8,
#     'pm10': 8,
#     'temp': 27,
#     'co2': None,
#     'humid': 72,
#     'topic': 'Dustboy/4042'}],
#   'info': {'topic': 'Dustboy/4042',
#    'project': 'Dustboy',
#    'id': '4042',
#    'lat': '19.642196',
#    'lon': '99.525286',
#    'name': 'โรงพยาบาลแม่สรวย จ. เชียงราย',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4062': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 18,
#     'pm10': 19,
#     'temp': 33,
#     'co2': None,
#     'humid': 59,
#     'topic': 'Dustboy/4062'}],
#   'info': {'topic': 'Dustboy/4062',
#    'project': 'Dustboy',
#    'id': '4062',
#    'lat': '13.904530',
#    'lon': '100.527630',
#    'name': 'หน้าเซ็นทรัลแจ้งวัฒนะ ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4064': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 34,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/4064'}],
#   'info': {'topic': 'Dustboy/4064',
#    'project': 'Dustboy',
#    'id': '4064',
#    'lat': '13.901940',
#    'lon': '100.505710',
#    'name': 'ซอยสถานสงเคราะห์คนพิการปากเกร็ด ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4065': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 16,
#     'pm10': 18,
#     'temp': 33,
#     'co2': None,
#     'humid': 100,
#     'topic': 'Dustboy/4065'}],
#   'info': {'topic': 'Dustboy/4065',
#    'project': 'Dustboy',
#    'id': '4065',
#    'lat': '13.938596',
#    'lon': '100.517700',
#    'name': 'ซอยสุขาประชาสวรรค์ 2 ตัด 3 ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4068': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 9,
#     'pm10': 11,
#     'temp': 34,
#     'co2': None,
#     'humid': 49,
#     'topic': 'Dustboy/4068'}],
#   'info': {'topic': 'Dustboy/4068',
#    'project': 'Dustboy',
#    'id': '4068',
#    'lat': '13.931635',
#    'lon': '100.507440',
#    'name': 'ปากซอยโรงเรียนวัดกู้ ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4069': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 10,
#     'pm10': 11,
#     'temp': 34,
#     'co2': None,
#     'humid': 58,
#     'topic': 'Dustboy/4069'}],
#   'info': {'topic': 'Dustboy/4069',
#    'project': 'Dustboy',
#    'id': '4069',
#    'lat': '13.906450',
#    'lon': '100.514730',
#    'name': 'หน้าบิ๊กชีแจ้งวัฒนะ ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4072': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 11,
#     'pm10': 12,
#     'temp': 33,
#     'co2': None,
#     'humid': 60,
#     'topic': 'Dustboy/4072'}],
#   'info': {'topic': 'Dustboy/4072',
#    'project': 'Dustboy',
#    'id': '4072',
#    'lat': '13.890772',
#    'lon': '100.513852',
#    'name': 'สามแยกติวานนท์-ปากเกร็ด 2 ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4077': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 12,
#     'pm10': 12,
#     'temp': 38,
#     'co2': None,
#     'humid': 83,
#     'topic': 'Dustboy/4077'}],
#   'info': {'topic': 'Dustboy/4077',
#    'project': 'Dustboy',
#    'id': '4077',
#    'lat': '13.911404',
#    'lon': '100.497929',
#    'name': 'หน้าโรงเรียนปากเกร็ด ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4078': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 13,
#     'pm10': 15,
#     'temp': 34,
#     'co2': None,
#     'humid': 51,
#     'topic': 'Dustboy/4078'}],
#   'info': {'topic': 'Dustboy/4078',
#    'project': 'Dustboy',
#    'id': '4078',
#    'lat': '13.899630',
#    'lon': '100.541560',
#    'name': 'หน้าโรงเรียนคลองเกลือ ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4079': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 11,
#     'pm10': 15,
#     'temp': 32,
#     'co2': None,
#     'humid': 62,
#     'topic': 'Dustboy/4079'}],
#   'info': {'topic': 'Dustboy/4079',
#    'project': 'Dustboy',
#    'id': '4079',
#    'lat': '13.924443',
#    'lon': '100.523624',
#    'name': 'ซอยสุขาประชาสวรรค์3 ซอย26 (รร. อัมพรไพศาล) ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/4080': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 11,
#     'pm10': 11,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/4080'}],
#   'info': {'topic': 'Dustboy/4080',
#    'project': 'Dustboy',
#    'id': '4080',
#    'lat': '13.915147',
#    'lon': '100.524006',
#    'name': 'สี่แยกสหกรณ์ 3 (ถนนเลี่ยงเมือง) ทน. ปากเกร็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5006': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 8,
#     'pm10': 8,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5006'}],
#   'info': {'topic': 'Dustboy/5006',
#    'project': 'Dustboy',
#    'id': '5006',
#    'lat': '18.306962',
#    'lon': '100.291156',
#    'name': 'รพ. ร้องกวาง จ. แพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5007': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 3,
#     'pm10': 3,
#     'temp': 33,
#     'co2': None,
#     'humid': 66,
#     'topic': 'Dustboy/5007'}],
#   'info': {'topic': 'Dustboy/5007',
#    'project': 'Dustboy',
#    'id': '5007',
#    'lat': '18.097426',
#    'lon': '100.201347',
#    'name': 'รพ.สต. ป่าแดง จ. แพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5008': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 14,
#     'pm10': 15,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5008'}],
#   'info': {'topic': 'Dustboy/5008',
#    'project': 'Dustboy',
#    'id': '5008',
#    'lat': '18.149402',
#    'lon': '100.146343',
#    'name': 'สำนักงานสาธารณสุขจังหวัดแพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5011': {'data': [{'time': '2023-08-18T13:00:00.000Z',
#     'pm1': None,
#     'pm25': 3,
#     'pm10': 3,
#     'temp': 32,
#     'co2': None,
#     'humid': 49,
#     'topic': 'Dustboy/5011'}],
#   'info': {'topic': 'Dustboy/5011',
#    'project': 'Dustboy',
#    'id': '5011',
#    'lat': '18.059812',
#    'lon': '100.117528',
#    'name': 'โรงพยาบาลสูงเม่น จ. แพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5013': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 4,
#     'pm10': 4,
#     'temp': 34,
#     'co2': None,
#     'humid': 63,
#     'topic': 'Dustboy/5013'}],
#   'info': {'topic': 'Dustboy/5013',
#    'project': 'Dustboy',
#    'id': '5013',
#    'lat': '18.207141',
#    'lon': '99.861997',
#    'name': 'รพ.สต. ผาคัน จ. แพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5019': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 8,
#     'pm10': 8,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5019'}],
#   'info': {'topic': 'Dustboy/5019',
#    'project': 'Dustboy',
#    'id': '5019',
#    'lat': '17.982854',
#    'lon': '100.054273',
#    'name': 'โรงพยาบาลสมเด็จพระยุพราชเด่นชัย จ. แพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5021': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 12,
#     'pm10': 13,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5021'}],
#   'info': {'topic': 'Dustboy/5021',
#    'project': 'Dustboy',
#    'id': '5021',
#    'lat': '18.089667',
#    'lon': '99.843886',
#    'name': 'โรงพยาบาลลอง จ. แพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5022': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 7,
#     'pm10': 7,
#     'temp': 35,
#     'co2': None,
#     'humid': 64,
#     'topic': 'Dustboy/5022'}],
#   'info': {'topic': 'Dustboy/5022',
#    'project': 'Dustboy',
#    'id': '5022',
#    'lat': '17.889293',
#    'lon': '99.598410',
#    'name': 'โรงพยาบาลวังชิ้น จ. แพร่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5023': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 3,
#     'pm10': 3,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5023'}],
#   'info': {'topic': 'Dustboy/5023',
#    'project': 'Dustboy',
#    'id': '5023',
#    'lat': '19.511812',
#    'lon': '98.514438',
#    'name': 'รพ.สต. เมืองน้อย จ. แม่ฮ่องสอน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5025': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 1,
#     'pm10': 1,
#     'temp': 31,
#     'co2': None,
#     'humid': 70,
#     'topic': 'Dustboy/5025'}],
#   'info': {'topic': 'Dustboy/5025',
#    'project': 'Dustboy',
#    'id': '5025',
#    'lat': '19.650582',
#    'lon': '98.093046',
#    'name': 'รพ.สต. นาปู่ป้อม อ. ปางมะผ้า จ. เเม่ฮ่องสอน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5027': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 5,
#     'pm10': 6,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5027'}],
#   'info': {'topic': 'Dustboy/5027',
#    'project': 'Dustboy',
#    'id': '5027',
#    'lat': '19.314346',
#    'lon': '97.986904',
#    'name': 'โรงพยาบาลธัญญารักษ์ แม่ฮ่องสอน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5030': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 7,
#     'pm10': 7,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5030'}],
#   'info': {'topic': 'Dustboy/5030',
#    'project': 'Dustboy',
#    'id': '5030',
#    'lat': '16.872994',
#    'lon': '99.131673',
#    'name': 'โรงพยาบาลสมเด็จพระเจ้าตากสินมหาราช จ. ตาก',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5031': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 2,
#     'pm10': 3,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5031'}],
#   'info': {'topic': 'Dustboy/5031',
#    'project': 'Dustboy',
#    'id': '5031',
#    'lat': '16.401232',
#    'lon': '98.695481',
#    'name': 'โรงพยาบาลพบพระ จ. ตาก',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5035': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 8,
#     'pm10': 8,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5035'}],
#   'info': {'topic': 'Dustboy/5035',
#    'project': 'Dustboy',
#    'id': '5035',
#    'lat': '17.308357',
#    'lon': '100.073916',
#    'name': 'โรงพยาบาลพิชัย จ. อุตรดิตถ์',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5050': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 6,
#     'pm10': 7,
#     'temp': 33,
#     'co2': None,
#     'humid': 64,
#     'topic': 'Dustboy/5050'}],
#   'info': {'topic': 'Dustboy/5050',
#    'project': 'Dustboy',
#    'id': '5050',
#    'lat': '19.350511',
#    'lon': '100.138234',
#    'name': 'เทศบาลตำบลห้วยข้าวก่ำ',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5052': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 23,
#     'pm10': 24,
#     'temp': 35,
#     'co2': None,
#     'humid': 60,
#     'topic': 'Dustboy/5052'}],
#   'info': {'topic': 'Dustboy/5052',
#    'project': 'Dustboy',
#    'id': '5052',
#    'lat': '19.190432',
#    'lon': '99.880380',
#    'name': 'ศูนย์ราชการจังหวัดพะเยา',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5053': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 35,
#     'pm10': 36,
#     'temp': 33,
#     'co2': None,
#     'humid': 66,
#     'topic': 'Dustboy/5053'}],
#   'info': {'topic': 'Dustboy/5053',
#    'project': 'Dustboy',
#    'id': '5053',
#    'lat': '19.190219',
#    'lon': '99.878112',
#    'name': 'โรงพยาบาลพะเยา',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5054': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 13,
#     'pm10': 13,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5054'}],
#   'info': {'topic': 'Dustboy/5054',
#    'project': 'Dustboy',
#    'id': '5054',
#    'lat': '19.299684',
#    'lon': '97.971889',
#    'name': 'โรงพยาบาลศรีสังวาลย์ จ. แม่ฮ่องสอน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5059': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 13,
#     'pm10': 14,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5059'}],
#   'info': {'topic': 'Dustboy/5059',
#    'project': 'Dustboy',
#    'id': '5059',
#    'lat': '13.798267',
#    'lon': '100.321855',
#    'name': ' กองกายภาพและสิ่งแวดล้อม',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5060': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 1,
#     'pm10': 1,
#     'temp': 33,
#     'co2': None,
#     'humid': 60,
#     'topic': 'Dustboy/5060'}],
#   'info': {'topic': 'Dustboy/5060',
#    'project': 'Dustboy',
#    'id': '5060',
#    'lat': '13.794105',
#    'lon': '100.321097',
#    'name': 'ศูนย์การเรียนรู้ ม. มหิดล (ศาลายา)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5061': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 14,
#     'pm10': 14,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5061'}],
#   'info': {'topic': 'Dustboy/5061',
#    'project': 'Dustboy',
#    'id': '5061',
#    'lat': '13.797405',
#    'lon': '100.321100',
#    'name': ' อาคารสิริวิทยา มหาวิทยาลัยมหิดล (ศาลายา)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5062': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 7,
#     'pm10': 7,
#     'temp': 34,
#     'co2': None,
#     'humid': 63,
#     'topic': 'Dustboy/5062'}],
#   'info': {'topic': 'Dustboy/5062',
#    'project': 'Dustboy',
#    'id': '5062',
#    'lat': '13.794338',
#    'lon': '100.325805',
#    'name': 'สำนักงานอธิการบดี ม. มหิดล (ศาลายา)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5071': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 5,
#     'pm10': 6,
#     'temp': 32,
#     'co2': None,
#     'humid': 62,
#     'topic': 'Dustboy/5071'}],
#   'info': {'topic': 'Dustboy/5071',
#    'project': 'Dustboy',
#    'id': '5071',
#    'lat': '7.213780',
#    'lon': '100.586816',
#    'name': 'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดสงขลา',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5072': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 6,
#     'pm10': 7,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5072'}],
#   'info': {'topic': 'Dustboy/5072',
#    'project': 'Dustboy',
#    'id': '5072',
#    'lat': '7.481985',
#    'lon': '99.492522',
#    'name': 'สํานักงานเทศบาลเมืองกันตัง จ. ตรัง',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5075': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 5,
#     'pm10': 5,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5075'}],
#   'info': {'topic': 'Dustboy/5075',
#    'project': 'Dustboy',
#    'id': '5075',
#    'lat': '18.531887',
#    'lon': '97.934792',
#    'name': 'รพ.สต. แม่ลาหลวง จ. แม่ฮ่องสอน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5089': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 28,
#     'pm10': 31,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5089'}],
#   'info': {'topic': 'Dustboy/5089',
#    'project': 'Dustboy',
#    'id': '5089',
#    'lat': '16.218548',
#    'lon': '103.893817',
#    'name': 'เทศบาลตำบลโคกสูง จ. ร้อยเอ็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5090': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 6,
#     'pm10': 7,
#     'temp': 37,
#     'co2': None,
#     'humid': 54,
#     'topic': 'Dustboy/5090'}],
#   'info': {'topic': 'Dustboy/5090',
#    'project': 'Dustboy',
#    'id': '5090',
#    'lat': '16.078544',
#    'lon': '103.641298',
#    'name': 'โรงพยาบาลส่งเสริมสุขภาพตำบลหนองบ้านหนองนาสร้าง จ. ร้อยเอ็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5091': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 16,
#     'pm10': 16,
#     'temp': 35,
#     'co2': None,
#     'humid': 62,
#     'topic': 'Dustboy/5091'}],
#   'info': {'topic': 'Dustboy/5091',
#    'project': 'Dustboy',
#    'id': '5091',
#    'lat': '16.216916',
#    'lon': '103.913690',
#    'name': 'รพ.สต. บ้านสองห้อง อ. โพนทอง จ. ร้อยเอ็ด',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5094': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 26,
#     'pm10': 28,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/5094'}],
#   'info': {'topic': 'Dustboy/5094',
#    'project': 'Dustboy',
#    'id': '5094',
#    'lat': '16.206474',
#    'lon': '103.097351',
#    'name': 'องค์การบริหารส่วนตำบลแก้งแก จ. มหาสารคาม',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5095': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 4,
#     'pm10': 4,
#     'temp': 35,
#     'co2': None,
#     'humid': 60,
#     'topic': 'Dustboy/5095'}],
# ...
#   'info': {'topic': 'Dustboy/5423',
#    'project': 'Dustboy',
#    'id': '5423',
#    'lat': '14.960684',
#    'lon': '102.098813',
#    'name': 'บก.ทภ.2 จ.นครราชสีมา (กอ.รมน.ภาค 2)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5427': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 10,
#     'pm10': 10,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5427'}],
#   'info': {'topic': 'Dustboy/5427',
#    'project': 'Dustboy',
#    'id': '5427',
#    'lat': '14.882227',
#    'lon': '103.492266',
#    'name': 'ศาลากลางจังหวัดสุรินทร์ (กอ.รมน.จังหวัดสุรินทร์)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5430': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 24,
#     'pm10': 25,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5430'}],
#   'info': {'topic': 'Dustboy/5430',
#    'project': 'Dustboy',
#    'id': '5430',
#    'lat': '18.335314',
#    'lon': '103.684516',
#    'name': 'ศาลากลางจังหวัดบึงกาฬ (กอ.รมน.จังหวัดบึงกาฬ)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5431': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 13,
#     'pm10': 13,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5431'}],
#   'info': {'topic': 'Dustboy/5431',
#    'project': 'Dustboy',
#    'id': '5431',
#    'lat': '17.222566',
#    'lon': '102.425943',
#    'name': 'ศาลากลางจังหวัดหนองบัวลำภู (กอ.รมน. หนองบัวลำภู)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5433': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 3,
#     'pm10': 3,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5433'}],
#   'info': {'topic': 'Dustboy/5433',
#    'project': 'Dustboy',
#    'id': '5433',
#    'lat': '19.300053',
#    'lon': '97.960503',
#    'name': 'วัดพระธาตุดอยกองมู อ.เมืองแม่ฮ่องสอน (กอ.รมน. แม่ฮ่องสอน)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5434': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 10,
#     'pm10': 12,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5434'}],
#   'info': {'topic': 'Dustboy/5434',
#    'project': 'Dustboy',
#    'id': '5434',
#    'lat': '15.353653',
#    'lon': '100.009549',
#    'name': 'สถานีอุตุนิยมวิทยาอุทัยธานี ต.น้ำซึม อ.เมืองอุทัยธานี (กอ.รมน. อุทัยธานี)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5444': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 7,
#     'pm10': 7,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5444'}],
#   'info': {'topic': 'Dustboy/5444',
#    'project': 'Dustboy',
#    'id': '5444',
#    'lat': '16.154765',
#    'lon': '103.306158',
#    'name': 'ศาลากลางจังหวัดมหาสารคาม (กอ.รมน.มหาสารคาม)',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5479': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 30,
#     'pm10': 32,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5479'}],
#   'info': {'topic': 'Dustboy/5479',
#    'project': 'Dustboy',
#    'id': '5479',
#    'lat': '15.784220',
#    'lon': '104.152550',
#    'name': 'สวนสาธารณะพญาแถน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5518': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 7,
#     'pm10': 9,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5518'}],
#   'info': {'topic': 'Dustboy/5518',
#    'project': 'Dustboy',
#    'id': '5518',
#    'lat': '19.574319',
#    'lon': '99.089211',
#    'name': 'บ้านหัวโท หมู่ที่ 6 ต.ปิงโค้ง อ.เชียงดาว จ.เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5521': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 7,
#     'pm10': 9,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5521'}],
#   'info': {'topic': 'Dustboy/5521',
#    'project': 'Dustboy',
#    'id': '5521',
#    'lat': '19.511793',
#    'lon': '99.090370',
#    'name': 'รร.บ้านออน จ.เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5526': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 22,
#     'pm10': 24,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5526'}],
#   'info': {'topic': 'Dustboy/5526',
#    'project': 'Dustboy',
#    'id': '5526',
#    'lat': '19.732860',
#    'lon': '98.892630',
#    'name': 'รพ.สต.บ้านแม่นะ จ.เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5578': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 28,
#     'pm10': 32,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5578'}],
#   'info': {'topic': 'Dustboy/5578',
#    'project': 'Dustboy',
#    'id': '5578',
#    'lat': '16.350677',
#    'lon': '100.789632',
#    'name': 'รพ.วังโป่ง จ.เพชรบูรณ์',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5582': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 1,
#     'pm10': 2,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5582'}],
#   'info': {'topic': 'Dustboy/5582',
#    'project': 'Dustboy',
#    'id': '5582',
#    'lat': '19.747070',
#    'lon': '99.143485',
#    'name': 'รพ.สต.บ้านปงตำ จ.เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5595': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 2,
#     'pm10': 2,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5595'}],
#   'info': {'topic': 'Dustboy/5595',
#    'project': 'Dustboy',
#    'id': '5595',
#    'lat': '17.406062',
#    'lon': '99.748860',
#    'name': 'ทม.ศรีสัชนาลัย (หลังใหม่) จ.สุโขทัย',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/5616': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 17,
#     'pm10': 20,
#     'temp': None,
#     'co2': None,
#     'humid': None,
#     'topic': 'Dustboy/5616'}],
#   'info': {'topic': 'Dustboy/5616',
#    'project': 'Dustboy',
#    'id': '5616',
#    'lat': '16.988528',
#    'lon': '100.327386',
#    'name': 'รพ.วัดโบสถ์ จ.พิษณุโลก',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/58': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 4,
#     'pm10': 5,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/58'}],
#   'info': {'topic': 'Dustboy/58',
#    'project': 'Dustboy',
#    'id': '58',
#    'lat': '19.524514',
#    'lon': '98.242973',
#    'name': 'รพ. ปางมะผ้า จ. แม่ฮ่องสอน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/6': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 14,
#     'pm10': 15,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/6'}],
#   'info': {'topic': 'Dustboy/6',
#    'project': 'Dustboy',
#    'id': '6',
#    'lat': '18.761371',
#    'lon': '98.931855',
#    'name': 'มหาวิทยาลัยเชียงใหม่ แคมปัสแม่เหียะ',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/65': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 28,
#     'pm10': 31,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/65'}],
#   'info': {'topic': 'Dustboy/65',
#    'project': 'Dustboy',
#    'id': '65',
#    'lat': '19.361707',
#    'lon': '98.437776',
#    'name': 'รพ. ปาย จ. แม่ฮ่องสอน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/71': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 9,
#     'pm10': 11,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/71'}],
#   'info': {'topic': 'Dustboy/71',
#    'project': 'Dustboy',
#    'id': '71',
#    'lat': '18.211468',
#    'lon': '100.660430',
#    'name': 'รพ. นาหมื่น จ. น่าน',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/81': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 19,
#     'pm10': 21,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/81'}],
#   'info': {'topic': 'Dustboy/81',
#    'project': 'Dustboy',
#    'id': '81',
#    'lat': '18.679562',
#    'lon': '98.381679',
#    'name': 'รพ.สต. แม่นาจร จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/84': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 18,
#     'pm10': 19,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/84'}],
#   'info': {'topic': 'Dustboy/84',
#    'project': 'Dustboy',
#    'id': '84',
#    'lat': '19.593243',
#    'lon': '98.961633',
#    'name': 'ทต. เมืองนะ จ. เชียงใหม่',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'Dustboy/85': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 26,
#     'pm10': 28,
#     'temp': 0,
#     'co2': None,
#     'humid': 0,
#     'topic': 'Dustboy/85'}],
#   'info': {'topic': 'Dustboy/85',
#    'project': 'Dustboy',
#    'id': '85',
#    'lat': '20.421067',
#    'lon': '99.982670',
#    'name': 'รพ.สต. เกาะช้าง จ. เชียงราย',
#    'tambol': None,
#    'amphoe': None,
#    'province': None}},
#  'nansensor/CU-S0029': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 5,
#     'pm10': 6,
#     'temp': 36.3,
#     'co2': None,
#     'humid': 65,
#     'topic': 'nansensor/CU-S0029'}],
#   'info': {'topic': 'nansensor/CU-S0029',
#    'project': 'nansensor',
#    'id': 'CU-S0029',
#    'lat': '19.058403',
#    'lon': '100.790855',
#    'name': 'องค์การบริหารส่วนตำบลศรีภูมิ',
#    'tambol': 'ศรีภูมิ',
#    'amphoe': 'ท่าวังผา',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0034': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 10,
#     'pm25': 12,
#     'pm10': 13,
#     'temp': 35.5,
#     'co2': None,
#     'humid': 64,
#     'topic': 'nansensor/CU-S0034'}],
#   'info': {'topic': 'nansensor/CU-S0034',
#    'project': 'nansensor',
#    'id': 'CU-S0034',
#    'lat': '19.178860',
#    'lon': '100.777670',
#    'name': 'องค์การบริหารส่วนตำบลผาตอ',
#    'tambol': 'ผาตอ',
#    'amphoe': 'ท่าวังผา',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0035': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 7,
#     'pm10': 7,
#     'temp': 35.3,
#     'co2': None,
#     'humid': 65,
#     'topic': 'nansensor/CU-S0035'}],
#   'info': {'topic': 'nansensor/CU-S0035',
#    'project': 'nansensor',
#    'id': 'CU-S0035',
#    'lat': '18.722192',
#    'lon': '101.008247',
#    'name': 'เทศบาลตำบลหนองแดง',
#    'tambol': 'หนองแดง',
#    'amphoe': 'แม่จริม',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0036': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 4,
#     'pm25': 5,
#     'pm10': 5,
#     'temp': 32.5,
#     'co2': None,
#     'humid': 64,
#     'topic': 'nansensor/CU-S0036'}],
#   'info': {'topic': 'nansensor/CU-S0036',
#    'project': 'nansensor',
#    'id': 'CU-S0036',
#    'lat': '19.208550',
#    'lon': '101.185284',
#    'name': 'องค์การบริหารส่วนตำบลดงพญา',
#    'tambol': 'ดงพญา',
#    'amphoe': 'บ่อเกลือ',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0042': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 7,
#     'pm10': 8,
#     'temp': 34.9,
#     'co2': None,
#     'humid': 61,
#     'topic': 'nansensor/CU-S0042'}],
#   'info': {'topic': 'nansensor/CU-S0042',
#    'project': 'nansensor',
#    'id': 'CU-S0042',
#    'lat': '19.089435',
#    'lon': '100.896897',
#    'name': 'อบต.ยม',
#    'tambol': 'ยม',
#    'amphoe': 'ท่าวังผา',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0045': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 6,
#     'pm25': 8,
#     'pm10': 8,
#     'temp': 37.1,
#     'co2': None,
#     'humid': 57,
#     'topic': 'nansensor/CU-S0045'}],
#   'info': {'topic': 'nansensor/CU-S0045',
#    'project': 'nansensor',
#    'id': 'CU-S0045',
#    'lat': '18.572993',
#    'lon': '100.782502',
#    'name': 'องค์การบริหารส่วนตำบลไหล่น่าน',
#    'tambol': 'ไหลน่าน',
#    'amphoe': 'เวียงสา',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0054': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 36.3,
#     'co2': None,
#     'humid': 57,
#     'topic': 'nansensor/CU-S0054'}],
#   'info': {'topic': 'nansensor/CU-S0054',
#    'project': 'nansensor',
#    'id': 'CU-S0054',
#    'lat': '19.149782',
#    'lon': '100.946654',
#    'name': 'เทศบาลตำบลศิลาแลง',
#    'tambol': 'ศิลาแลง',
#    'amphoe': 'ปัว',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0059': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 6,
#     'pm10': 7,
#     'temp': 31.6,
#     'co2': None,
#     'humid': 76,
#     'topic': 'nansensor/CU-S0059'}],
#   'info': {'topic': 'nansensor/CU-S0059',
#    'project': 'nansensor',
#    'id': 'CU-S0059',
#    'lat': '18.644196',
#    'lon': '101.011780',
#    'name': 'องค์การบริหารส่วนตำบลน้ำพาง',
#    'tambol': 'น้ำพาง',
#    'amphoe': 'แม่จริม',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0067': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 3,
#     'pm25': 4,
#     'pm10': 4,
#     'temp': 34,
#     'co2': None,
#     'humid': 62,
#     'topic': 'nansensor/CU-S0067'}],
#   'info': {'topic': 'nansensor/CU-S0067',
#    'project': 'nansensor',
#    'id': 'CU-S0067',
#    'lat': '19.176190',
#    'lon': '100.950550',
#    'name': 'องค์การบริหารส่วนตำบลวรนคร',
#    'tambol': 'วรนคร',
#    'amphoe': 'ปัว',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0071': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 0,
#     'pm25': 0,
#     'pm10': 0,
#     'temp': 37.4,
#     'co2': None,
#     'humid': 49,
#     'topic': 'nansensor/CU-S0071'}],
#   'info': {'topic': 'nansensor/CU-S0071',
#    'project': 'nansensor',
#    'id': 'CU-S0071',
#    'lat': '18.799662',
#    'lon': '100.733299',
#    'name': 'องค์การบริหารส่วนจังหวัดน่าน',
#    'tambol': 'ไชยสถาน',
#    'amphoe': 'เมืองน่าน',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0079': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 6,
#     'pm10': 7,
#     'temp': 34.8,
#     'co2': None,
#     'humid': 55,
#     'topic': 'nansensor/CU-S0079'}],
#   'info': {'topic': 'nansensor/CU-S0079',
#    'project': 'nansensor',
#    'id': 'CU-S0079',
#    'lat': '18.300600',
#    'lon': '100.594360',
#    'name': 'องค์การบริหารส่วนตำบลสันทะ',
#    'tambol': 'สันทะ',
#    'amphoe': 'นาน้อย',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0081': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 6,
#     'pm25': 8,
#     'pm10': 8,
#     'temp': 35.9,
#     'co2': None,
#     'humid': 60,
#     'topic': 'nansensor/CU-S0081'}],
#   'info': {'topic': 'nansensor/CU-S0081',
#    'project': 'nansensor',
#    'id': 'CU-S0081',
#    'lat': '18.910000',
#    'lon': '100.940000',
#    'name': 'องค์การบริหารส่วนตำบลดุ่พงษ์',
#    'tambol': 'ดุ่พงษ์',
#    'amphoe': 'สันติสุข',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0085': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 5,
#     'pm25': 6,
#     'pm10': 7,
#     'temp': 36.6,
#     'co2': None,
#     'humid': 59,
#     'topic': 'nansensor/CU-S0085'}],
#   'info': {'topic': 'nansensor/CU-S0085',
#    'project': 'nansensor',
#    'id': 'CU-S0085',
#    'lat': '18.797941',
#    'lon': '100.714249',
#    'name': 'องค์การบริหารส่วนตำบลถืมตอง',
#    'tambol': 'ถืมตอง',
#    'amphoe': 'เมืองน่าน',
#    'province': 'น่าน'}},
#  'nansensor/CU-S0098': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': 8,
#     'pm25': 10,
#     'pm10': 10,
#     'temp': 36.1,
#     'co2': None,
#     'humid': 60,
#     'topic': 'nansensor/CU-S0098'}],
#   'info': {'topic': 'nansensor/CU-S0098',
#    'project': 'nansensor',
#    'id': 'CU-S0098',
#    'lat': '18.732440',
#    'lon': '100.824770',
#    'name': 'องค์การบริหารส่วนตำบลน้ำเกี้ยน',
#    'tambol': 'น้ำเกี้ยน',
#    'amphoe': 'ภูเพียง',
#    'province': 'น่าน'}},
#  'PTT/ptt.mainoffice': {'data': [{'time': '2023-08-18T14:00:00.000Z',
#     'pm1': None,
#     'pm25': 4,
#     'pm10': None,
#     'temp': 32.5,
#     'co2': None,
#     'humid': 65,
#     'topic': 'PTT/ptt.mainoffice'}],
#   'info': {'topic': 'PTT/ptt.mainoffice',
#    'project': 'PTT',
#    'id': 'ptt.mainoffice',
#    'lat': '13.818353',
#    'lon': '100.558332',
#    'name': 'สำนักงานใหญ่ ปตท.',
#    'tambol': 'จตุจักร',
#    'amphoe': 'จคุจักร',
#    'province': 'กรุงเทพ'}}}

# %%
all_sensors = list(realtime.keys())
print('they are'+' '+str(len(all_sensors))+' '+'sensors.')
# Out:
# they are 251 sensors.

# %%
print(all_sensors)
# Out:
# ['cusensor2/0424D01F9C9C', 'cusensor2/0C44F5C40A24', 'cusensor2/40F5203F0828', 'cusensor2/40F5203F7FBF', 'cusensor2/40F5203F88E0', 'cusensor2/60019440B7A6', 'cusensor2/60019440B7B7', 'cusensor2/60019440B808', 'cusensor2/60019440B80B', 'cusensor2/60019440B8BA', 'cusensor2/68C63A8E5B80', 'cusensor2/68C63A8E5BB6', 'cusensor2/869405031319016', 'cusensor2/869405031319123', 'cusensor2/B01ED01F9C9C', 'cusensor2/D478F5C40A24', 'cusensor3/240AC4588CF8', 'cusensor3/240AC4589680', 'cusensor3/240AC458FE8C', 'cusensor3/240AC4592908', 'cusensor3/240AC4C656F8', 'cusensor3/240AC4C66068', 'cusensor3/246F289D7CE8', 'cusensor3/246F289D7F1C', 'cusensor3/246F289E11D4', 'cusensor3/246F289E1BE4', 'cusensor3/246F289E906C', 'cusensor3/246F289EA1B4', 'cusensor3/246F289EA56C', 'cusensor3/246F289EA798', 'cusensor3/246F28B45C80', 'cusensor3/246F28B4FFB8', 'cusensor3/7C9EBDF4DCE4', 'cusensor3/7C9EBDF4DE94', 'cusensor3/7C9EBDF4E32C', 'cusensor3/7C9EBDF4E430', 'cusensor3/7C9EBDF4E780', 'cusensor3/7C9EBDF4E7C4', 'cusensor3/7C9EBDF4EAA4', 'cusensor3/7C9EBDF50438', 'cusensor3/8CAAB584DBF0', 'cusensor3/8CAAB5851AD4', 'cusensor3/8CAAB58527DC', 'cusensor3/8CAAB5852984', 'cusensor3/B8F009CD03A8', 'cusensor3/B8F009CD07DC', 'cusensor3/B8F009CD113C', 'cusensor3/B8F009CD1878', 'cusensor3/B8F009CD18F4', 'cusensor3/B8F009CD1DB4', 'cusensor3/B8F009CD1F20', 'Dustboy/110', 'Dustboy/13', 'Dustboy/18', 'Dustboy/24', 'Dustboy/25', 'Dustboy/26', 'Dustboy/30', 'Dustboy/3002', 'Dustboy/31', 'Dustboy/33', 'Dustboy/34', 'Dustboy/37', 'Dustboy/38', 'Dustboy/4', 'Dustboy/4010', 'Dustboy/4032', 'Dustboy/4039', 'Dustboy/4042', 'Dustboy/4062', 'Dustboy/4064', 'Dustboy/4065', 'Dustboy/4068', 'Dustboy/4069', 'Dustboy/4072', 'Dustboy/4077', 'Dustboy/4078', 'Dustboy/4079', 'Dustboy/4080', 'Dustboy/5006', 'Dustboy/5007', 'Dustboy/5008', 'Dustboy/5011', 'Dustboy/5013', 'Dustboy/5019', 'Dustboy/5021', 'Dustboy/5022', 'Dustboy/5023', 'Dustboy/5025', 'Dustboy/5027', 'Dustboy/5030', 'Dustboy/5031', 'Dustboy/5035', 'Dustboy/5050', 'Dustboy/5052', 'Dustboy/5053', 'Dustboy/5054', 'Dustboy/5059', 'Dustboy/5060', 'Dustboy/5061', 'Dustboy/5062', 'Dustboy/5071', 'Dustboy/5072', 'Dustboy/5075', 'Dustboy/5089', 'Dustboy/5090', 'Dustboy/5091', 'Dustboy/5094', 'Dustboy/5095', 'Dustboy/5096', 'Dustboy/5099', 'Dustboy/51', 'Dustboy/5100', 'Dustboy/5101', 'Dustboy/5151', 'Dustboy/5160', 'Dustboy/5163', 'Dustboy/5167', 'Dustboy/5168', 'Dustboy/5169', 'Dustboy/5171', 'Dustboy/5174', 'Dustboy/5175', 'Dustboy/5177', 'Dustboy/5178', 'Dustboy/5180', 'Dustboy/5182', 'Dustboy/5183', 'Dustboy/5185', 'Dustboy/5188', 'Dustboy/5189', 'Dustboy/5190', 'Dustboy/5197', 'Dustboy/5199', 'Dustboy/5201', 'Dustboy/5202', 'Dustboy/5203', 'Dustboy/5204', 'Dustboy/5205', 'Dustboy/5208', 'Dustboy/5209', 'Dustboy/5213', 'Dustboy/5217', 'Dustboy/5229', 'Dustboy/5230', 'Dustboy/5232', 'Dustboy/5233', 'Dustboy/5234', 'Dustboy/5237', 'Dustboy/5238', 'Dustboy/5239', 'Dustboy/5240', 'Dustboy/5242', 'Dustboy/5243', 'Dustboy/5246', 'Dustboy/5249', 'Dustboy/5263', 'Dustboy/5264', 'Dustboy/5265', 'Dustboy/5267', 'Dustboy/5268', 'Dustboy/5270', 'Dustboy/5273', 'Dustboy/5274', 'Dustboy/5277', 'Dustboy/5278', 'Dustboy/5281', 'Dustboy/5285', 'Dustboy/5286', 'Dustboy/5287', 'Dustboy/5288', 'Dustboy/5289', 'Dustboy/5297', 'Dustboy/5298', 'Dustboy/5299', 'Dustboy/5300', 'Dustboy/5301', 'Dustboy/5302', 'Dustboy/5303', 'Dustboy/5304', 'Dustboy/5306', 'Dustboy/5313', 'Dustboy/5318', 'Dustboy/5327', 'Dustboy/5328', 'Dustboy/5330', 'Dustboy/5332', 'Dustboy/5333', 'Dustboy/5334', 'Dustboy/5338', 'Dustboy/5340', 'Dustboy/5343', 'Dustboy/5376', 'Dustboy/5377', 'Dustboy/5378', 'Dustboy/5379', 'Dustboy/5385', 'Dustboy/5387', 'Dustboy/5388', 'Dustboy/5389', 'Dustboy/5390', 'Dustboy/5394', 'Dustboy/5397', 'Dustboy/5399', 'Dustboy/5401', 'Dustboy/5404', 'Dustboy/5405', 'Dustboy/5408', 'Dustboy/5412', 'Dustboy/5414', 'Dustboy/5415', 'Dustboy/5416', 'Dustboy/5418', 'Dustboy/5422', 'Dustboy/5423', 'Dustboy/5427', 'Dustboy/5430', 'Dustboy/5431', 'Dustboy/5433', 'Dustbo ...

# %%
PM25 = []
for i in all_sensors:
  PM = realtime[i]['data'][0]['pm25']
  PM25.append(PM)

# %%
Time = []
for i in all_sensors:
  time = realtime[i]['data'][0]['time']
  Time.append(time)

# %%
PM10 = []
for i in all_sensors:
  PM = realtime[i]['data'][0]['pm10']
  PM10.append(PM)

# %%
Temp = []
for i in all_sensors:
  temp = realtime[i]['data'][0]['temp']
  Temp.append(temp)

# %%
Hum = []
for i in all_sensors:
  hum = realtime[i]['data'][0]['humid']
  Hum.append(hum)

# %% [markdown]
# *   **sensor** อยู่ใน list ชื่อ **all_sensors**
# *   **time** อยู่ใน list ชื่อ **Time**
# *   **pm 2.5** อยู่ใน list ชื่อ **PM25**
# *   **pm 10** อยู่ใน list ชื่อ **PM10**
# *   **temp** อยู่ใน list ชื่อ **Temp**
# *   **humid** อยู่ใน list ชื่อ **Hum**

# %% [markdown]
# **จัดเก็บทุกอย่างเป็น csv**

# %%
import csv

list1 = all_sensors
list2 = Time
list3 = PM25
list4 = PM10
list5 = Temp
list6 = Hum

# Combine the lists into a single list of tuples
combined_lists = list(zip(list1, list2, list3,list4,list5,list6))

# Define the filename for the CSV file
filename = 'PM.csv'

# Write the data to the CSV file
with open(filename, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Sensor', 'Time', 'PM2.5','PM10','Temp','Humid'])  # Write the header
    writer.writerows(combined_lists)  # Write the data rows

print(f"The data has been written to {filename}.")
# Out:
# The data has been written to PM.csv.
